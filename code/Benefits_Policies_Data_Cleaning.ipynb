# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
df = pd.read_csv("../data_original/24_Benefits_Inclusion_anon.csv")
#move company name & benchmark to the front 
second_col = df.pop('benchmark_group')
df.insert(0, 'benchmark_group', second_col)
df.reset_index(drop=True)

first_col = df.pop('Organization')
df.insert(0, 'org', first_col)
df.reset_index(drop=True)

# when indexing from 0, column 82 is where inclusion (ICTC) starts
df = df.iloc[: , :84]

# %%
#Renaming columns based on Question # followed by _A/B/C/etc if a multiple selection
#Question numbering is from the survey at: https://gender-ideal.org/the-assessment

df.rename(columns={'Benefits & Policies: Does your organization provide a universal family leave policy to all employees?':'Q1',
    'Less than 12 weeks for primary caregiver':'Q2_A',
    'Less than 12 weeks for secondary caregiver':'Q2_B',
    '12-25 weeks for primary caregiver': 'Q2_C',
    '12-25 weeks for secondary caregiver': 'Q2_D',
    '26-51 weeks for primary caregiver': 'Q2_E',
    '26-51 for secondary caregiver': 'Q2_F',
    '52+ weeks for primary caregiver': 'Q2_G',
    '52+ weeks for secondary caregiver': 'Q2_H',
    'None for primary caregiver': 'Q2_I',
    'None for secondary caregiver': 'Q2_J',
    'Benefits & Policies: Does the plan above explicitly provide fully paid leave for adoption or surrogacy?':'Q3',
    'Benefits & Policies: During the last 12 months, what % of qualified employees took their full paid family leave available? If your policy distinguishes between primary and secondary caregivers, respond to this question only considering all qualified primary caregivers.':'Q4',
    'Benefits & Policies: If your policy differentiates between primary and secondary caregivers, during the last 12 months, what % of secondary caregivers took their full paid family leave available?  If your policy does not differentiate, just respond with N/A.':'Q5',
    'Benefits & Policies: In addition to paid family-leave, does your workplace offer additional unpaid leave options for caregivers?':'Q6',
    'Benefits & Policies: Does your organization have a written policy regarding flexible phase-in schedules for employees returning from family leave?':'Q7',
    'Benefits & Policies: Does your organization provide guidance to all managers to develop supportive phase-in schedules for employees returning from family leave?':'Q8',
    'Benefits & Policies: Do all offices and facilities have lactation rooms (windowless or covered windows, locked door, refrigerator and sink available) that are accessible to all lactating employees?':'Q9',
    'Benefits & Policies: Are there on-site or nearby childcare options for at least 80% of your offices/facilities?':'Q10',
    'Benefits & Policies: Does your organization subsidize the cost of childcare as a benefit available to all employees? ':'Q11',
    'Benefits & Policies: Does your organization cover the cost of the following: ':'Q12', 
    'Other':'Q12_Other',
    'Laundry services':'Q13_A',
    'Grocery shopping services':'Q13_B',
    'Meal prep options':'Q13_C',
    'On-site tutors*':'Q13_D',
    'On-site primary and urgent care*':'Q13_E',
    'None':'Q13_None',
    'Other.1':'Q13_Other',
    'Regular work-from-home schedules':'Q14_A',
    'As-Needed work-from-home schedules':'Q14_B',
    '100% remote work-from-home schedules':'Q14_C',
    'Condensed work-hour schedules':'Q14_D',
    'Job-sharing opportunities':'Q14_E',
    'Flexible work hours (employee determines schedule based on pre-determined hourly total)':'Q14_F',
    'None.1':'Q14_None',
    'Other.2':'Q14_Other',
    'N/A, no hourly employees':'Q15_A',
    'Set shift schedules (advanced shift scheduling)':'Q15_B',
    'Shift flexibility (allow for shift-swapping and trading amongst employees)':'Q15_C',
    'Guaranteed minimum payments (regardless of shift cancellations)':'Q15_D',
    'None.2':'Q15_None',
    'Other.3':'Q15_Other',
    'Stated commitment against harassment (ie - a zero tolerance policy must be followed with clear statements of the behavior that will not be tolerated)':'Q16_A',
    'Definitions of harassment that cover sexual harassment and harassment based on gender':'Q16_B',
    'Clear definitions and examples covering  inappropriate behavior and inappropriate language':'Q16_C',
    'Confidentiality and non-retaliation statements as part of the policy':'Q16_D',
    'Reporting and accountability policies for the harassment policy':'Q16_E',
    'None.3':'Q16_None',
    'Other.4':'Q16_Other',
    'Benefits & Policies: Does your organization have a publicly-posted policy that defines gender identity and sexual orientation discrimination, and that states a zero tolerance harassment and discrimination policy?':'Q17',
    'Clear guidance on what to expect from the whistleblower process, with clarity on how issues are elevated':'Q18_A',
    'Whistleblowers with assured neutrality':'Q18_B',
    'Ensures protection and anonymity of employees':'Q18_C',
    'Articulates a fair process for evaluating concerns as they are reported':'Q18_D',
    'Articulates how whistleblowers will be informed and engaged in the process':'Q18_E',
    'None.4':'Q18_None',
    'Other.5':'Q18_Other',
    'Sexual harassment':'Q19_A',
    'Gender identity':'Q19_B',
    'Sexual orientation discrimination':'Q19_C',
    'No':'Q19_D',
    'Benefits & Policies: In the last 12 months, have there been any gender-related or sexual harassment or discrimination claims brought by an employee or former employee against another employee of the company?':'Q20',
    'Benefits & Policies: Tell us about the outcome or status of those claims.':'Q21',
    'Benefits & Policies:  Does your organization have a written policy regarding the treatment of an employee who has violated the harassment or discrimination policy that includes escalation if unresolved over time ':'Q22',
    'Benefits & Policies:  During the last 12 months, what % of employees who have harassed or discriminated against one or more colleagues experienced these repercussions?':'Q23',
    'Benefits & Policies:  During the last two years, have all workers who have violated discrimination or harassment policies received additional bias and discrimination training?':'Q24',
    'Benefits & Policies:  Have any workers who have a documented pattern of harassing or discriminating behavior been terminated? ':'Q25',
    'Contraception coverage (male and female)':'Q26_A',
    'Abortion services':'Q26_B',
    'Fertility treatment coverage (including IVF)':'Q26_C',
    'Egg freezing':'Q26_D',
    'Gender Reassignment surgery':'Q26_E',
    'Other.6':'Q26_Other',
    'Employee only':'Q27_A',
    'Married spouses (same and opposite sex)':'Q27_B',
    'Domestic partners (same and opposite sex)':'Q27_C',
    'Other.7':'Q27_Other',
    'Benefits & Policies:  Do part-time employees who work 20+ hours qualify for health insurance?':'Q28',
    'Benefits & Policies:  Is the ratio of monthly health insurance premium to lowest paid worker greater than 10%?':'Q29',
    "Benefits & Policies:  Does your organization have written gender transition guidelines that documents policies or practices on issues pertinent to a workplace gender transition, including supportive guidance on restroom and facilities access, dress code and internal record-keeping that fully recognize an employee's full-time gender presentation and maximize privacy for the employee. ":'Q30',
    'Benefits & Policies: Before we move to the next section, is there anything else you want to tell us about how your organization tracks, reports on or is working to improve its benefits and policies system?':'Q31'},inplace=True)

# %%
df.columns
# Out:
# Index(['org', 'benchmark_group', 'Q1', 'Q2_A', 'Q2_B', 'Q2_C', 'Q2_D', 'Q2_E',
#        'Q2_F', 'Q2_G', 'Q2_H', 'Q2_I', 'Q2_J', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7',
#        'Q8', 'Q9', 'Q10', 'Q11', 'Q12', 'Q12_Other', 'Q13_A', 'Q13_B', 'Q13_C',
#        'Q13_D', 'Q13_E', 'Q13_None', 'Q13_Other', 'Q14_A', 'Q14_B', 'Q14_C',
#        'Q14_D', 'Q14_E', 'Q14_F', 'Q14_None', 'Q14_Other', 'Q15_A', 'Q15_B',
#        'Q15_C', 'Q15_D', 'Q15_None', 'Q15_Other', 'Q16_A', 'Q16_B', 'Q16_C',
#        'Q16_D', 'Q16_E', 'Q16_None', 'Q16_Other', 'Q17', 'Q18_A', 'Q18_B',
#        'Q18_C', 'Q18_D', 'Q18_E', 'Q18_None', 'Q18_Other', 'Q19_A', 'Q19_B',
#        'Q19_C', 'Q19_D', 'Q20', 'Q21', 'Q22', 'Q23', 'Q24', 'Q25', 'Q26_A',
#        'Q26_B', 'Q26_C', 'Q26_D', 'Q26_E', 'Q26_Other', 'Q27_A', 'Q27_B',
#        'Q27_C', 'Q27_Other', 'Q28', 'Q29', 'Q30', 'Q31'],
#       dtype='object')

# %%
df.drop(columns=['Q5'],inplace=True)
df.drop(columns=['Q31'],inplace=True)

df.reset_index(drop=True)
# Out:
#            org benchmark_group  Q1                                      Q2_A  \
# 0   Company 1X      Technology   1                                       NaN
# 1   Company 1W       NonProfit   1  Less than 12 weeks for primary caregiver
# 2   Company 1V         Finance   1                                       NaN
# 3   Company 1U         Finance   1  Less than 12 weeks for primary caregiver
# 4   Company 1T      Technology   1                                       NaN
# 5   Company 1S      Technology   1                                       NaN
# 6   Company 1R      Technology   1                                       NaN
# 7   Company 1Q         Finance   1                                       NaN
# 8   Company 1P             NaN   1  Less than 12 weeks for primary caregiver
# 9   Company 1O      Technology   1                                       NaN
# 10  Company 1N      Technology   1  Less than 12 weeks for primary caregiver
# 11  Company 1M             NaN   1                                       NaN
# 12  Company 1L       NonProfit   0                                       NaN
# 13  Company 1K       NonProfit   1  Less than 12 weeks for primary caregiver
# 14  Company 1J         Finance   1                                       NaN
# 15  Company 1I       NonProfit   1  Less than 12 weeks for primary caregiver
# 16  Company 1H      Technology   1                                       NaN
# 17  Company 1G             NaN   1  Less than 12 weeks for primary caregiver
# 18  Company 1F         Finance   1  Less than 12 weeks for primary caregiver
# 19  Company 1E       NonProfit   1                                       NaN
# 20  Company 1D      Technology   1                                       NaN
# 21  Company 1C             NaN   1  Less than 12 weeks for primary caregiver
# 22  Company 1B         Finance   0                                       NaN
# 23  Company 1A         Finance   1                                       NaN
#
#                                           Q2_B  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3   Less than 12 weeks for secondary caregiver
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8   Less than 12 weeks for secondary caregiver
# 9                                          NaN
# 10  Less than 12 weeks for secondary caregiver
# 11                                         NaN
# 12                                         NaN
# 13  Less than 12 weeks for secondary caregiver
# 14                                         NaN
# 15  Less than 12 weeks for secondary caregiver
# 16                                         NaN
# 17  Less than 12 weeks for secondary caregiver
# 18  Less than 12 weeks for secondary caregiver
# 19                                         NaN
# 20                                         NaN
# 21  Less than 12 weeks for secondary caregiver
# 22  Less than 12 weeks for secondary caregiver
# 23                                         NaN
#
#                                  Q2_C                                 Q2_D  \
# 0   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 5   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 6                                 NaN                                  NaN
# 7   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 8                                 NaN                                  NaN
# 9   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 10                                NaN                                  NaN
# 11                                NaN                                  NaN
# 12  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 13                                NaN                                  NaN
# 14                                NaN                                  NaN
# 15                                NaN                                  NaN
# 16  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 17                                NaN                                  NaN
# 18                                NaN                                  NaN
# 19  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 20  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 21                                NaN                                  NaN
# 22  12-25 weeks for primary caregiver                                  NaN
# 23  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
#
#     Q2_E  Q2_F  Q2_G  ...         Q26_D                        Q26_E  \
# 0    NaN   NaN   NaN  ...           NaN  Gender Reassignment surgery
# 1    NaN   NaN   NaN  ...           NaN                          NaN
# 2    NaN   NaN   NaN  ...  Egg freezing  Gender Reassignment surgery
# 3    NaN   NaN   NaN  ...           NaN                          NaN
# 4    NaN   NaN   NaN  ...           NaN                          NaN
# 5    NaN   NaN   NaN  ...  Egg freezing  Gender Reassignment surgery
# 6    NaN   NaN   NaN  ...           NaN                          NaN
# 7    NaN   NaN   NaN  ...           NaN                          NaN
# 8    NaN   NaN   NaN  ...           NaN  Gender Reassignment surgery
# 9    NaN   NaN   NaN  ...           NaN                          NaN
# 10   NaN   NaN   NaN  ...           NaN                          NaN
# 11   NaN   NaN   NaN  ...           NaN                          NaN
# 12   NaN   NaN   NaN  ...           NaN                          NaN
# 13   NaN   NaN   NaN  ...           NaN                          NaN
# 14   NaN   NaN   NaN  ...           NaN  Gender Reassignment surgery
# 15   NaN   NaN   NaN  ...           NaN                          NaN
# 16   NaN   NaN   NaN  ...           NaN                          NaN
# 17   NaN   NaN   NaN  ...           NaN                          NaN
# 18   NaN   NaN   NaN  ...           NaN                          NaN
# 19   NaN   NaN   NaN  ...           NaN                          NaN
# 20   NaN   NaN   NaN  ...           NaN                          NaN
# 21   NaN   NaN   NaN  ...           NaN                          NaN
# 22   NaN   NaN   NaN  ...           NaN                          NaN
# 23   NaN   NaN   NaN  ...           NaN                          NaN
#
#                                             Q26_Other          Q27_A  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN  Employee only
# 10                                                NaN  Employee only
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN  Employee only
# 14                                                NaN            NaN
# 15                                                NaN  Employee only
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19  not sure, standard medical plans with no exclu...            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22                                                NaN  Employee only
# 23                                                NaN            NaN
#
#                                       Q27_B  \
# 0   Married spouses (same and opposite sex)
# 1   Married spouses (same and opposite sex)
# 2                                       NaN
# 3   Married spouses (same and opposite sex)
# 4   Married spouses (same and opposite sex)
# 5   Married spouses (same and opposite sex)
# 6   Married spouses (same and opposite sex)
# 7   Married spouses (same and opposite sex)
# 8   Married spouses (same and opposite sex)
# 9   Married spouses (same and opposite sex)
# 10  Married spouses (same and opposite sex)
# 11                                      NaN
# 12  Married spouses (same and opposite sex)
# 13  Married spouses (same and opposite sex)
# 14                                      NaN
# 15  Married spouses (same and opposite sex)
# 16  Married spouses (same and opposite sex)
# 17                                      NaN
# 18  Married spouses (same and opposite sex)
# 19  Married spouses (same and opposite sex)
# 20                                      NaN
# 21                                      NaN
# 22  Married spouses (same and opposite sex)
# 23  Married spouses (same and opposite sex)
#
#                                         Q27_C  Q27_Other  Q28  Q29  \
# 0   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 1   Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 2                                         NaN        NaN  0.0  0.0
# 3   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 4   Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 5   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 6   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 7   Domestic partners (same and opposite sex)        NaN  1.0  0.0
# 8   Domestic partners (same and opposite sex)        NaN  1.0  0.0
# 9   Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 10  Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 11                                        NaN        NaN  0.0  NaN
# 12                                        NaN        NaN  0.0  1.0
# 13  Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 14  Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 15  Domestic partners (same and opposite sex)        NaN  NaN  0.0
# 16  Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 17  Domestic partners (same and opposite sex)        NaN  1.0  1.0
# 18                                        NaN        NaN  0.0  0.0
# 19  Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 20                                        NaN        NaN  NaN  NaN
# 21                                        NaN        NaN  NaN  NaN
# 22  Domestic partners (same and opposite sex)        NaN  NaN  0.0
# 23  Domestic partners (same and opposite sex)        NaN  0.0  0.0
#
#                                                   Q30
# 0   In progress (not yet circulated amongst employ...
# 1                                                 NaN
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6   In progress (not yet circulated amongst employ...
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# 13                                                 No
# 14  In progress (not yet circulated amongst employ...
# 15                                                 No
# 16                                                 No
# 17                                                 No
# 18                                                 No
# 19                                                Yes
# 20                                                NaN
# 21                                                NaN
# 22                                                 No
# 23  In progress (not yet circulated amongst employ...
#
# [24 rows x 82 columns]

# %%
df.columns
# Out:
# Index(['org', 'benchmark_group', 'Q1', 'Q2_A', 'Q2_B', 'Q2_C', 'Q2_D', 'Q2_E',
#        'Q2_F', 'Q2_G', 'Q2_H', 'Q2_I', 'Q2_J', 'Q3', 'Q4', 'Q6', 'Q7', 'Q8',
#        'Q9', 'Q10', 'Q11', 'Q12', 'Q12_Other', 'Q13_A', 'Q13_B', 'Q13_C',
#        'Q13_D', 'Q13_E', 'Q13_None', 'Q13_Other', 'Q14_A', 'Q14_B', 'Q14_C',
#        'Q14_D', 'Q14_E', 'Q14_F', 'Q14_None', 'Q14_Other', 'Q15_A', 'Q15_B',
#        'Q15_C', 'Q15_D', 'Q15_None', 'Q15_Other', 'Q16_A', 'Q16_B', 'Q16_C',
#        'Q16_D', 'Q16_E', 'Q16_None', 'Q16_Other', 'Q17', 'Q18_A', 'Q18_B',
#        'Q18_C', 'Q18_D', 'Q18_E', 'Q18_None', 'Q18_Other', 'Q19_A', 'Q19_B',
#        'Q19_C', 'Q19_D', 'Q20', 'Q21', 'Q22', 'Q23', 'Q24', 'Q25', 'Q26_A',
#        'Q26_B', 'Q26_C', 'Q26_D', 'Q26_E', 'Q26_Other', 'Q27_A', 'Q27_B',
#        'Q27_C', 'Q27_Other', 'Q28', 'Q29', 'Q30'],
#       dtype='object')

# %%
df['Q12'].fillna('Other', inplace=True)
df.drop(columns=['Q12_Other'],inplace=True)
df.reset_index(drop=True)
# Out:
#            org benchmark_group  Q1                                      Q2_A  \
# 0   Company 1X      Technology   1                                       NaN
# 1   Company 1W       NonProfit   1  Less than 12 weeks for primary caregiver
# 2   Company 1V         Finance   1                                       NaN
# 3   Company 1U         Finance   1  Less than 12 weeks for primary caregiver
# 4   Company 1T      Technology   1                                       NaN
# 5   Company 1S      Technology   1                                       NaN
# 6   Company 1R      Technology   1                                       NaN
# 7   Company 1Q         Finance   1                                       NaN
# 8   Company 1P             NaN   1  Less than 12 weeks for primary caregiver
# 9   Company 1O      Technology   1                                       NaN
# 10  Company 1N      Technology   1  Less than 12 weeks for primary caregiver
# 11  Company 1M             NaN   1                                       NaN
# 12  Company 1L       NonProfit   0                                       NaN
# 13  Company 1K       NonProfit   1  Less than 12 weeks for primary caregiver
# 14  Company 1J         Finance   1                                       NaN
# 15  Company 1I       NonProfit   1  Less than 12 weeks for primary caregiver
# 16  Company 1H      Technology   1                                       NaN
# 17  Company 1G             NaN   1  Less than 12 weeks for primary caregiver
# 18  Company 1F         Finance   1  Less than 12 weeks for primary caregiver
# 19  Company 1E       NonProfit   1                                       NaN
# 20  Company 1D      Technology   1                                       NaN
# 21  Company 1C             NaN   1  Less than 12 weeks for primary caregiver
# 22  Company 1B         Finance   0                                       NaN
# 23  Company 1A         Finance   1                                       NaN
#
#                                           Q2_B  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3   Less than 12 weeks for secondary caregiver
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8   Less than 12 weeks for secondary caregiver
# 9                                          NaN
# 10  Less than 12 weeks for secondary caregiver
# 11                                         NaN
# 12                                         NaN
# 13  Less than 12 weeks for secondary caregiver
# 14                                         NaN
# 15  Less than 12 weeks for secondary caregiver
# 16                                         NaN
# 17  Less than 12 weeks for secondary caregiver
# 18  Less than 12 weeks for secondary caregiver
# 19                                         NaN
# 20                                         NaN
# 21  Less than 12 weeks for secondary caregiver
# 22  Less than 12 weeks for secondary caregiver
# 23                                         NaN
#
#                                  Q2_C                                 Q2_D  \
# 0   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 5   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 6                                 NaN                                  NaN
# 7   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 8                                 NaN                                  NaN
# 9   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 10                                NaN                                  NaN
# 11                                NaN                                  NaN
# 12  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 13                                NaN                                  NaN
# 14                                NaN                                  NaN
# 15                                NaN                                  NaN
# 16  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 17                                NaN                                  NaN
# 18                                NaN                                  NaN
# 19  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 20  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 21                                NaN                                  NaN
# 22  12-25 weeks for primary caregiver                                  NaN
# 23  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
#
#     Q2_E  Q2_F  Q2_G  ...         Q26_D                        Q26_E  \
# 0    NaN   NaN   NaN  ...           NaN  Gender Reassignment surgery
# 1    NaN   NaN   NaN  ...           NaN                          NaN
# 2    NaN   NaN   NaN  ...  Egg freezing  Gender Reassignment surgery
# 3    NaN   NaN   NaN  ...           NaN                          NaN
# 4    NaN   NaN   NaN  ...           NaN                          NaN
# 5    NaN   NaN   NaN  ...  Egg freezing  Gender Reassignment surgery
# 6    NaN   NaN   NaN  ...           NaN                          NaN
# 7    NaN   NaN   NaN  ...           NaN                          NaN
# 8    NaN   NaN   NaN  ...           NaN  Gender Reassignment surgery
# 9    NaN   NaN   NaN  ...           NaN                          NaN
# 10   NaN   NaN   NaN  ...           NaN                          NaN
# 11   NaN   NaN   NaN  ...           NaN                          NaN
# 12   NaN   NaN   NaN  ...           NaN                          NaN
# 13   NaN   NaN   NaN  ...           NaN                          NaN
# 14   NaN   NaN   NaN  ...           NaN  Gender Reassignment surgery
# 15   NaN   NaN   NaN  ...           NaN                          NaN
# 16   NaN   NaN   NaN  ...           NaN                          NaN
# 17   NaN   NaN   NaN  ...           NaN                          NaN
# 18   NaN   NaN   NaN  ...           NaN                          NaN
# 19   NaN   NaN   NaN  ...           NaN                          NaN
# 20   NaN   NaN   NaN  ...           NaN                          NaN
# 21   NaN   NaN   NaN  ...           NaN                          NaN
# 22   NaN   NaN   NaN  ...           NaN                          NaN
# 23   NaN   NaN   NaN  ...           NaN                          NaN
#
#                                             Q26_Other          Q27_A  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN  Employee only
# 10                                                NaN  Employee only
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN  Employee only
# 14                                                NaN            NaN
# 15                                                NaN  Employee only
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19  not sure, standard medical plans with no exclu...            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22                                                NaN  Employee only
# 23                                                NaN            NaN
#
#                                       Q27_B  \
# 0   Married spouses (same and opposite sex)
# 1   Married spouses (same and opposite sex)
# 2                                       NaN
# 3   Married spouses (same and opposite sex)
# 4   Married spouses (same and opposite sex)
# 5   Married spouses (same and opposite sex)
# 6   Married spouses (same and opposite sex)
# 7   Married spouses (same and opposite sex)
# 8   Married spouses (same and opposite sex)
# 9   Married spouses (same and opposite sex)
# 10  Married spouses (same and opposite sex)
# 11                                      NaN
# 12  Married spouses (same and opposite sex)
# 13  Married spouses (same and opposite sex)
# 14                                      NaN
# 15  Married spouses (same and opposite sex)
# 16  Married spouses (same and opposite sex)
# 17                                      NaN
# 18  Married spouses (same and opposite sex)
# 19  Married spouses (same and opposite sex)
# 20                                      NaN
# 21                                      NaN
# 22  Married spouses (same and opposite sex)
# 23  Married spouses (same and opposite sex)
#
#                                         Q27_C  Q27_Other  Q28  Q29  \
# 0   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 1   Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 2                                         NaN        NaN  0.0  0.0
# 3   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 4   Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 5   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 6   Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 7   Domestic partners (same and opposite sex)        NaN  1.0  0.0
# 8   Domestic partners (same and opposite sex)        NaN  1.0  0.0
# 9   Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 10  Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 11                                        NaN        NaN  0.0  NaN
# 12                                        NaN        NaN  0.0  1.0
# 13  Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 14  Domestic partners (same and opposite sex)        NaN  0.0  1.0
# 15  Domestic partners (same and opposite sex)        NaN  NaN  0.0
# 16  Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 17  Domestic partners (same and opposite sex)        NaN  1.0  1.0
# 18                                        NaN        NaN  0.0  0.0
# 19  Domestic partners (same and opposite sex)        NaN  0.0  0.0
# 20                                        NaN        NaN  NaN  NaN
# 21                                        NaN        NaN  NaN  NaN
# 22  Domestic partners (same and opposite sex)        NaN  NaN  0.0
# 23  Domestic partners (same and opposite sex)        NaN  0.0  0.0
#
#                                                   Q30
# 0   In progress (not yet circulated amongst employ...
# 1                                                 NaN
# 2                                                  No
# 3                                                  No
# 4                                                  No
# 5                                                  No
# 6   In progress (not yet circulated amongst employ...
# 7                                                  No
# 8                                                  No
# 9                                                  No
# 10                                                 No
# 11                                                 No
# 12                                                 No
# 13                                                 No
# 14  In progress (not yet circulated amongst employ...
# 15                                                 No
# 16                                                 No
# 17                                                 No
# 18                                                 No
# 19                                                Yes
# 20                                                NaN
# 21                                                NaN
# 22                                                 No
# 23  In progress (not yet circulated amongst employ...
#
# [24 rows x 81 columns]

# %%
df[['Q26_A',
       'Q26_B', 'Q26_C', 'Q26_D', 'Q26_E', 'Q26_Other']]
df["Q26_F"] = np.nan
df.reset_index(drop=True)
df.loc[df["org"].isin(["Company 1W","Company 1T","Company 1R","Company 1M","Company 1F","Company 1D","Company 1C","Company 1A"]),"Q26_F"] = "None"

# %%
df.drop(columns=['Q21'],inplace=True)
df.reset_index(drop=True)
# Out:
#            org benchmark_group  Q1                                      Q2_A  \
# 0   Company 1X      Technology   1                                       NaN
# 1   Company 1W       NonProfit   1  Less than 12 weeks for primary caregiver
# 2   Company 1V         Finance   1                                       NaN
# 3   Company 1U         Finance   1  Less than 12 weeks for primary caregiver
# 4   Company 1T      Technology   1                                       NaN
# 5   Company 1S      Technology   1                                       NaN
# 6   Company 1R      Technology   1                                       NaN
# 7   Company 1Q         Finance   1                                       NaN
# 8   Company 1P             NaN   1  Less than 12 weeks for primary caregiver
# 9   Company 1O      Technology   1                                       NaN
# 10  Company 1N      Technology   1  Less than 12 weeks for primary caregiver
# 11  Company 1M             NaN   1                                       NaN
# 12  Company 1L       NonProfit   0                                       NaN
# 13  Company 1K       NonProfit   1  Less than 12 weeks for primary caregiver
# 14  Company 1J         Finance   1                                       NaN
# 15  Company 1I       NonProfit   1  Less than 12 weeks for primary caregiver
# 16  Company 1H      Technology   1                                       NaN
# 17  Company 1G             NaN   1  Less than 12 weeks for primary caregiver
# 18  Company 1F         Finance   1  Less than 12 weeks for primary caregiver
# 19  Company 1E       NonProfit   1                                       NaN
# 20  Company 1D      Technology   1                                       NaN
# 21  Company 1C             NaN   1  Less than 12 weeks for primary caregiver
# 22  Company 1B         Finance   0                                       NaN
# 23  Company 1A         Finance   1                                       NaN
#
#                                           Q2_B  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3   Less than 12 weeks for secondary caregiver
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8   Less than 12 weeks for secondary caregiver
# 9                                          NaN
# 10  Less than 12 weeks for secondary caregiver
# 11                                         NaN
# 12                                         NaN
# 13  Less than 12 weeks for secondary caregiver
# 14                                         NaN
# 15  Less than 12 weeks for secondary caregiver
# 16                                         NaN
# 17  Less than 12 weeks for secondary caregiver
# 18  Less than 12 weeks for secondary caregiver
# 19                                         NaN
# 20                                         NaN
# 21  Less than 12 weeks for secondary caregiver
# 22  Less than 12 weeks for secondary caregiver
# 23                                         NaN
#
#                                  Q2_C                                 Q2_D  \
# 0   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 5   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 6                                 NaN                                  NaN
# 7   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 8                                 NaN                                  NaN
# 9   12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 10                                NaN                                  NaN
# 11                                NaN                                  NaN
# 12  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 13                                NaN                                  NaN
# 14                                NaN                                  NaN
# 15                                NaN                                  NaN
# 16  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 17                                NaN                                  NaN
# 18                                NaN                                  NaN
# 19  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 20  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
# 21                                NaN                                  NaN
# 22  12-25 weeks for primary caregiver                                  NaN
# 23  12-25 weeks for primary caregiver  12-25 weeks for secondary caregiver
#
#     Q2_E  Q2_F  Q2_G  ...                        Q26_E  \
# 0    NaN   NaN   NaN  ...  Gender Reassignment surgery
# 1    NaN   NaN   NaN  ...                          NaN
# 2    NaN   NaN   NaN  ...  Gender Reassignment surgery
# 3    NaN   NaN   NaN  ...                          NaN
# 4    NaN   NaN   NaN  ...                          NaN
# 5    NaN   NaN   NaN  ...  Gender Reassignment surgery
# 6    NaN   NaN   NaN  ...                          NaN
# 7    NaN   NaN   NaN  ...                          NaN
# 8    NaN   NaN   NaN  ...  Gender Reassignment surgery
# 9    NaN   NaN   NaN  ...                          NaN
# 10   NaN   NaN   NaN  ...                          NaN
# 11   NaN   NaN   NaN  ...                          NaN
# 12   NaN   NaN   NaN  ...                          NaN
# 13   NaN   NaN   NaN  ...                          NaN
# 14   NaN   NaN   NaN  ...  Gender Reassignment surgery
# 15   NaN   NaN   NaN  ...                          NaN
# 16   NaN   NaN   NaN  ...                          NaN
# 17   NaN   NaN   NaN  ...                          NaN
# 18   NaN   NaN   NaN  ...                          NaN
# 19   NaN   NaN   NaN  ...                          NaN
# 20   NaN   NaN   NaN  ...                          NaN
# 21   NaN   NaN   NaN  ...                          NaN
# 22   NaN   NaN   NaN  ...                          NaN
# 23   NaN   NaN   NaN  ...                          NaN
#
#                                             Q26_Other          Q27_A  \
# 0                                                 NaN            NaN
# 1                                                 NaN            NaN
# 2                                                 NaN            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5                                                 NaN            NaN
# 6                                                 NaN            NaN
# 7                                                 NaN            NaN
# 8                                                 NaN            NaN
# 9                                                 NaN  Employee only
# 10                                                NaN  Employee only
# 11                                                NaN            NaN
# 12                                                NaN            NaN
# 13                                                NaN  Employee only
# 14                                                NaN            NaN
# 15                                                NaN  Employee only
# 16                                                NaN            NaN
# 17                                                NaN            NaN
# 18                                                NaN            NaN
# 19  not sure, standard medical plans with no exclu...            NaN
# 20                                                NaN            NaN
# 21                                                NaN            NaN
# 22                                                NaN  Employee only
# 23                                                NaN            NaN
#
#                                       Q27_B  \
# 0   Married spouses (same and opposite sex)
# 1   Married spouses (same and opposite sex)
# 2                                       NaN
# 3   Married spouses (same and opposite sex)
# 4   Married spouses (same and opposite sex)
# 5   Married spouses (same and opposite sex)
# 6   Married spouses (same and opposite sex)
# 7   Married spouses (same and opposite sex)
# 8   Married spouses (same and opposite sex)
# 9   Married spouses (same and opposite sex)
# 10  Married spouses (same and opposite sex)
# 11                                      NaN
# 12  Married spouses (same and opposite sex)
# 13  Married spouses (same and opposite sex)
# 14                                      NaN
# 15  Married spouses (same and opposite sex)
# 16  Married spouses (same and opposite sex)
# 17                                      NaN
# 18  Married spouses (same and opposite sex)
# 19  Married spouses (same and opposite sex)
# 20                                      NaN
# 21                                      NaN
# 22  Married spouses (same and opposite sex)
# 23  Married spouses (same and opposite sex)
#
#                                         Q27_C Q27_Other  Q28  Q29  \
# 0   Domestic partners (same and opposite sex)       NaN  0.0  0.0
# 1   Domestic partners (same and opposite sex)       NaN  0.0  1.0
# 2                                         NaN       NaN  0.0  0.0
# 3   Domestic partners (same and opposite sex)       NaN  0.0  0.0
# 4   Domestic partners (same and opposite sex)       NaN  0.0  1.0
# 5   Domestic partners (same and opposite sex)       NaN  0.0  0.0
# 6   Domestic partners (same and opposite sex)       NaN  0.0  0.0
# 7   Domestic partners (same and opposite sex)       NaN  1.0  0.0
# 8   Domestic partners (same and opposite sex)       NaN  1.0  0.0
# 9   Domestic partners (same and opposite sex)       NaN  0.0  1.0
# 10  Domestic partners (same and opposite sex)       NaN  0.0  1.0
# 11                                        NaN       NaN  0.0  NaN
# 12                                        NaN       NaN  0.0  1.0
# 13  Domestic partners (same and opposite sex)       NaN  0.0  1.0
# 14  Domestic partners (same and opposite sex)       NaN  0.0  1.0
# 15  Domestic partners (same and opposite sex)       NaN  NaN  0.0
# 16  Domestic partners (same and opposite sex)       NaN  0.0  0.0
# 17  Domestic partners (same and opposite sex)       NaN  1.0  1.0
# 18                                        NaN       NaN  0.0  0.0
# 19  Domestic partners (same and opposite sex)       NaN  0.0  0.0
# 20                                        NaN       NaN  NaN  NaN
# 21                                        NaN       NaN  NaN  NaN
# 22  Domestic partners (same and opposite sex)       NaN  NaN  0.0
# 23  Domestic partners (same and opposite sex)       NaN  0.0  0.0
#
#                                                   Q30  Q26_F
# 0   In progress (not yet circulated amongst employ...    NaN
# 1                                                 NaN   None
# 2                                                  No    NaN
# 3                                                  No    NaN
# 4                                                  No   None
# 5                                                  No    NaN
# 6   In progress (not yet circulated amongst employ...   None
# 7                                                  No    NaN
# 8                                                  No    NaN
# 9                                                  No    NaN
# 10                                                 No    NaN
# 11                                                 No   None
# 12                                                 No    NaN
# 13                                                 No    NaN
# 14  In progress (not yet circulated amongst employ...    NaN
# 15                                                 No    NaN
# 16                                                 No    NaN
# 17                                                 No    NaN
# 18                                                 No   None
# 19                                                Yes    NaN
# 20                                                NaN   None
# 21                                                NaN   None
# 22                                                 No    NaN
# 23  In progress (not yet circulated amongst employ...   None
#
# [24 rows x 81 columns]

# %%
#Write out to csv
df.to_csv("benefits_clean_final.csv")
