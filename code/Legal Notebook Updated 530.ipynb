# %%
# Import pandas, numPy & dataset
import pandas as pd
import numpy as np
path = "C:\Leadership_Customers_Legal.csv"

# %%
# Briefly review the data
seg = pd.read_csv(path)
seg.head(5)
# Out:
#   Leadership Demographics: Has your organization conducted a review to determine whether the diversity of your workplace reflects the diversity of the localities in which your offices/facilities are located?  If you have multiple offices or facilities, your response should capture at least 80% of your workforce.  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Leadership Demographics: If yes, how closely does your total workforce reflect the diversity of your local region?  \
# 0                                                NaN
# 1  Minimal to no disparities (ie - the differenti...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Total Number of Workers  % Workers who identify as Women  \
# 0                   1481.0                             34.0
# 1                      6.0                            100.0
# 2                     37.0                             15.0
# 3                     56.0                             39.0
# 4                    181.0                             50.0
#
#    % Women who identify as Black or African American  \
# 0                                                6.0
# 1                                               33.0
# 2                                                NaN
# 3                                                2.0
# 4                                                6.0
#
#    %  Women who identify as Latina  %  Women who identify as Asian  \
# 0                              4.0                            22.0
# 1                             66.0                            16.0
# 2                              NaN                             NaN
# 3                              9.0                             4.0
# 4                              7.0                             5.0
#
#    % Women who identify as Native American/Alaskan/Pacific Islander:  \
# 0                                                1.0
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                0.0
#
#    % Women who identify as Mixed Race:  % Women who identify as LGBTQ:  ...  \
# 0                                  5.0                             NaN  ...
# 1                                 16.0                            33.0  ...
# 2                                  NaN                             2.0  ...
# 3                                  2.0                             5.0  ...
# 4                                  3.0                             NaN  ...
#
#    Legal Compliance: Do employees have a collective bargaining agreement?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?  \
# 0                                                NaN
# 1                                                1.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#   Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?  \
# 0                                                NaN
# 1                                                0.0
# 2                                                0.0
# 3                                                1.0
# 4                                                0.0
#
#    You've done it!  Congratulations on completing the Gender IDEAL Assessment.  Before you go, let us know how you would rate the assessment.  \
# 0                                                  8
# 1                                                  8
# 2                                                  8
# 3                                                  7
# 4                                                  8
#
#    Before you go, are there any last bits of feedback you can share?  Feedback will help us continuously improve.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Organization  benchmark_group       number_of_employees   number_of_years  \
# 0    Company 1X       Technology      1000-4,999 Employees        5-14 years
# 1    Company 1W        NonProfit  Fewer than 100 Employees  15 or more years
# 2    Company 1V          Finance  Fewer than 100 Employees        5-14 years
# 3    Company 1U          Finance  Fewer than 100 Employees  15 or more years
# 4    Company 1T       Technology         100-249 Employees        5-14 years
#
#                                            workforce
# 0             At least 80% of employees are Salaried
# 1  We have a mixed workforce of hourly and salari...
# 2             At least 80% of employees are Salaried
# 3             At least 80% of employees are Salaried
# 4  We have a mixed workforce of hourly and salari...
#
# [5 rows x 101 columns]

# %%
# Retrieve info on data set
seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Columns: 101 entries, Leadership Demographics: Has your organization conducted a review to determine whether the diversity of your workplace reflects the diversity of the localities in which your offices/facilities are located?  If you have multiple offices or facilities, your response should capture at least 80% of your workforce. to workforce
# dtypes: float64(64), int64(7), object(30)
# memory usage: 19.1+ KB

# %%
# Describe the numerical columns of the data set
seg.describe()
# Out:
#        Total Number of Workers  % Workers who identify as Women  \
# count                23.000000                        23.000000
# mean                248.434783                        84.478261
# std                 433.147658                       143.693129
# min                   6.000000                        15.000000
# 25%                  36.000000                        38.500000
# 50%                  57.000000                        49.000000
# 75%                 198.500000                        72.000000
# max                1481.000000                       734.000000
#
#        % Women who identify as Black or African American  \
# count                                          22.000000
# mean                                            9.681818
# std                                            10.416957
# min                                             0.000000
# 25%                                             3.250000
# 50%                                             5.500000
# 75%                                            11.500000
# max                                            35.000000
#
#        %  Women who identify as Latina  %  Women who identify as Asian  \
# count                        20.000000                       20.000000
# mean                          8.400000                        9.500000
# std                          14.430961                        9.976288
# min                           0.000000                        0.000000
# 25%                           1.750000                        4.000000
# 50%                           4.000000                        6.000000
# 75%                           9.250000                        9.250000
# max                          66.000000                       36.000000
#
#        % Women who identify as Native American/Alaskan/Pacific Islander:  \
# count                                          18.000000
# mean                                            1.944444
# std                                             6.168919
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.750000
# max                                            26.000000
#
#        % Women who identify as Mixed Race:  % Women who identify as LGBTQ:  \
# count                            21.000000                       13.000000
# mean                              4.333333                        7.384615
# std                               6.521758                       11.376426
# min                               0.000000                        0.000000
# 25%                               0.000000                        0.000000
# 50%                               2.000000                        2.000000
# 75%                               5.000000                        7.000000
# max                              26.000000                       33.000000
#
#        % Women with disabilities  % Persons who identify as Gender non-binary  \
# count                  12.000000                                    11.000000
# mean                    5.416667                                     0.090909
# std                    14.164349                                     0.301511
# min                     0.000000                                     0.000000
# 25%                     0.000000                                     0.000000
# 50%                     0.000000                                     0.000000
# 75%                     3.250000                                     0.000000
# max                    50.000000                                     1.000000
#
#        ...  \
# count  ...
# mean   ...
# std    ...
# min    ...
# 25%    ...
# 50%    ...
# 75%    ...
# max    ...
#
#        Customers, Contractors & Suppliers: What % of procurement is sourced from women-owned and gender-diverse led businesses?  \
# count                                           8.000000
# mean                                            1.875000
# std                                             3.720119
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.250000
# max                                            10.000000
#
#        Customers, Contractors & Suppliers: Does the organization have a written policy regarding gender equity that specifies the gender-related benefits and practices that a contractor or subcontractor must comply with?  \
# count                                          24.000000
# mean                                            0.083333
# std                                             0.282330
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Legal Compliance: Does your organization have a written non-discrimination or equal employment opportunity policy that  applies to all employees globally and which specifically references "race", "ethnicity", "religion", "socio-economic status", "sexual orientation" and "gender identity" that is distributed to employees through a handbook or other publicly-available place and included in all job descriptions?  \
# count                                          24.000000
# mean                                            0.958333
# std                                             0.204124
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims?   \
# count                                          22.000000
# mean                                            0.090909
# std                                             0.294245
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Legal Compliance: Does your organization have any litigation regarding harassment claims?   \
# count                                          22.000000
# mean                                            0.045455
# std                                             0.213201
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Legal Compliance: Over the last 5 years, how much has the organization paid in settlements on discrimination or harassment suits?  \
# count                                               16.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Legal Compliance: Do employees have a collective bargaining agreement?  \
# count                                          24.000000
# mean                                            0.083333
# std                                             0.282330
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?  \
# count                                          21.000000
# mean                                            0.190476
# std                                             0.402374
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?  \
# count                                          22.000000
# mean                                            0.363636
# std                                             0.492366
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        You've done it!  Congratulations on completing the Gender IDEAL Assessment.  Before you go, let us know how you would rate the assessment.
# count                                          24.000000
# mean                                            7.750000
# std                                             0.944089
# min                                             6.000000
# 25%                                             7.000000
# 50%                                             8.000000
# 75%                                             8.000000
# max                                            10.000000
#
# [8 rows x 71 columns]

# %%
# Retrieve a list of column names for dropping
seg.columns
# Out:
# Index(['Leadership Demographics: Has your organization conducted a review to determine whether the diversity of your workplace reflects the diversity of the localities in which your offices/facilities are located?  If you have multiple offices or facilities, your response should capture at least 80% of your workforce.',
#        'Leadership Demographics: If yes, how closely does your total workforce reflect the diversity of your local region?',
#        'Total Number of Workers', '% Workers who identify as Women',
#        '% Women who identify as Black or African American',
#        '%  Women who identify as Latina', '%  Women who identify as Asian',
#        '% Women who identify as Native American/Alaskan/Pacific Islander:',
#        '% Women who identify as Mixed Race:', '% Women who identify as LGBTQ:',
#        ...
#        'Legal Compliance: Do employees have a collective bargaining agreement?',
#        'Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?',
#        'Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?',
#        'You've done it!  Congratulations on completing the Gender IDEAL Assessment.  Before you go, let us know how you would rate the assessment.',
#        'Before you go, are there any last bits of feedback you can share?  Feedback will help us continuously improve.',
#        'Organization', 'benchmark_group', 'number_of_employees',
#        'number_of_years', 'workforce'],
#       dtype='object', length=101)

# %%
# Drop unncessary columns
seg = seg.drop(columns = ['Leadership Demographics: Has your organization conducted a review to determine whether the diversity of your workplace reflects the diversity of the localities in which your offices/facilities are located?  If you have multiple offices or facilities, your response should capture at least 80% of your workforce.',
       'Leadership Demographics: If yes, how closely does your total workforce reflect the diversity of your local region?',
       'Total Number of Workers', '% Workers who identify as Women',
       '% Women who identify as Black or African American',
       '%  Women who identify as Latina', '%  Women who identify as Asian',
       '% Women who identify as Native American/Alaskan/Pacific Islander:',
       '% Women who identify as Mixed Race:', '% Women who identify as LGBTQ:',
       '% Women with disabilities',
       '% Persons who identify as Gender non-binary',
       'Give us feedback - how challenging is it to provide demographic details for your workforce to the degree asked above?',
       '% Managers who identify as Women',
       '% Women managers who identify as Black or African American',
       '%  Women managers who identify as Latina',
       '%  Women managers who identify as Asian',
       '% Women managers who identify as Native American/Alaskan/Pacific Islander:',
       '% Women managers who identify as Mixed-Race:',
       '% Women managers who identify as LGBTQ:',
       '% Women managers with disabilities',
       '% managers who identify as Gender non-binary',
       'Give us feedback - how challenging is it to provide demographic details for your workforce to the degree asked above?.1',
       '% Executive management who identify as Women',
       '% Women executive managers who identify as Black or African American',
       '%  Women executive managers who identify as Latina',
       '%  Women executive managers who identify as Asian',
       '% Women executive managers who identify as Native American/Alaskan/Pacific Islander:',
       '% Women executive managers who identify as Mixed-Race:',
       '% Women executive managers who identify as LGBTQ:',
       '% Women executive managers with disabilities',
       '% executive managers who identify as Gender non-binary',
       'Give us feedback - how challenging is it to provide demographic details for your workforce to the degree asked above?.2',
       '% C-Suite Level who identify as Women',
       '% Women C-Suite Level who identify as Black or African American',
       '%  Women C-Suite Level who identify as Latina',
       '%  Women C-Suite Level who identify as Asian',
       '% Women C-Suite Level who identify as Native American/Alaskan/Pacific Islander:',
       '% Women C-Suite Level who identify as Mixed-Race:',
       '% Women C-Suite Level who identify as LGBTQ:',
       '% Women C-Suite Level with disabilities',
       '% C-Suite Level who identify as Gender non-binary',
       'Give us feedback - how challenging is it to provide demographic details for your workforce to the degree asked above?.3',
       '% Board of Directors or Governing Body who identify as Women',
       '% Women Board of Directors or Governing Body who identify as Black or African American',
       '%  Women Board of Directors or Governing Body who identify as Latina',
       '%  Women Board of Directors or Governing Body who identify as Asian',
       '% Women Board of Directors or Governing Body who identify as Native American/Alaskan/Pacific Islander:',
       '% Women Board of Directors or Governing Body who identify as Mixed-Race:',
       '% Women Board of Directors or Governing Body who identify as LGBTQ:',
       '% Women Board of Directors or Governing Body with disabilities',
       '% Board of Directors or Governing Body who identify as Gender non-binary',
       'Give us feedback - how challenging is it to provide demographic details for your workforce to the degree asked above?.4',
       'Our organization is not-for-profit.',
       '% Ownership who identify as Women',
       '% Women Ownership who identify as Black or African American',
       '%  Women Ownership who identify as Latina',
       '%  Women Ownership who identify as Asian',
       '% Women Ownership who identify as Native American/Alaskan/Pacific Islander:',
       '% Women Ownership who identify as Mixed-Race:',
       '% Women Ownership who identify as LGBTQ:',
       '% Women Ownership with disabilities',
       '% Ownership who identify as Gender non-binary',
       'Give us feedback - how challenging is it to provide demographic details for your workforce to the degree asked above?.5',
       'C-Suite', 'Board/Advisory Bodies', 'Senior Management', 'Management',
       'Mentorship Programs', 'Internal Promotions', 'No',
       'In the last 12 months, did your organization make progress toward achieving gender representation targets?',
       'Leadership Demographics: Before we move to the next section, is there anything else you want to tell us about how your organization tracks, reports on or seeks to change its leadership demographics?', 
       "You've done it!  Congratulations on completing the Gender IDEAL Assessment.  Before you go, let us know how you would rate the assessment.",
       'Before you go, are there any last bits of feedback you can share?  Feedback will help us continuously improve.', 'benchmark_group', 'number_of_employees',
       'number_of_years', 'workforce', 'Customers, Contractors & Suppliers: What % of your products or services sold have a gender focus?', 'Customers, Contractors & Suppliers: What % of procurement is sourced from women-owned and gender-diverse led businesses?',  'Customers, Contractors & Suppliers: Before we move to the next section, is there anything else you want to tell us about how your organization aligns its gender equity and diversity goals with customers, contractors and suppliers?','Customers, Contractors & Suppliers: Is  your product or service designed specifically to address gender needs in a way that competing products or services are not?',
       'Customers, Contractors & Suppliers: In the design of your products or services, has your organization explicitly tested how products or services are used by different genders and designed and tested products with the needs of those different users in mind?',
       'Customers, Contractors & Suppliers: Does your workplace have policies in place to ensure gender bias is eliminated from marketing materials?',
       'Customers, Contractors & Suppliers: Does the organization have a written policy that suppliers are expected to meet regarding gender equity and diversity standards?',
       "Customers, Contractors & Suppliers: Is there a policy to review potential suppliers to confirm alignment with your organization's position on gender equity and diversity?",
       'Customers, Contractors & Suppliers: Does the organization review and discuss compliance with its gender equity policy prior to signing a contract with a supplier?',
       'Customers, Contractors & Suppliers: Does the organization have a written policy regarding gender equity that specifies the gender-related benefits and practices that a contractor or subcontractor must comply with?',
       'Customers, Contractors & Suppliers: Does the organization review and discuss compliance with its gender equity policy prior to signing a contract with a potential contractor or subcontractor?', 'Legal Compliance: If there is current discrimination or EEOC litigation pending, please provide details.', 'Legal Compliance: If there is current discrimination or EEOC litigation pending, please provide details..1',
       'Legal Compliance: Over the last 5 years, how much has the organization paid in settlements on discrimination or harassment suits?',
       'Legal Compliance: Describe how and with what frequency your organization ensures compliance with all federal, state and local EEOC mandates.'])
seg.columns
# Out:
# Index(['Legal Compliance: Does your organization have a written non-discrimination or equal employment opportunity policy that  applies to all employees globally and which specifically references "race", "ethnicity", "religion", "socio-economic status", "sexual orientation" and "gender identity" that is distributed to employees through a handbook or other publicly-available place and included in all job descriptions?',
#        'Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims? ',
#        'Legal Compliance: Does your organization have any litigation regarding harassment claims? ',
#        'Legal Compliance: Do employees have a collective bargaining agreement?',
#        'Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?',
#        'Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?',
#        'Organization'],
#       dtype='object')

# %%
# Change blank value in the applicable columns to No Response
seg['Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims? '] = seg['Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims? '].fillna('No response')
seg['Legal Compliance: Does your organization have any litigation regarding harassment claims? '] = seg['Legal Compliance: Does your organization have any litigation regarding harassment claims? '].fillna('No response')
seg['Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?'] = seg['Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?'].fillna('No Response')
seg['Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?'] = seg['Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?'].fillna('No Response')

# %%
# Review updated data set to ensure unncessary columns are dropped
seg.head(5)
# Out:
#    Legal Compliance: Does your organization have a written non-discrimination or equal employment opportunity policy that  applies to all employees globally and which specifically references "race", "ethnicity", "religion", "socio-economic status", "sexual orientation" and "gender identity" that is distributed to employees through a handbook or other publicly-available place and included in all job descriptions?  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  0
# 4                                                  1
#
#   Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims?   \
# 0                                        No response
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#   Legal Compliance: Does your organization have any litigation regarding harassment claims?   \
# 0                                        No response
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  1
#
#    Legal Compliance: Do employees have a collective bargaining agreement?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?  \
# 0                                        No Response
# 1                                                  1
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#   Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?  \
# 0                                        No Response
# 1                                                  0
# 2                                                  0
# 3                                                  1
# 4                                                  0
#
#   Organization
# 0   Company 1X
# 1   Company 1W
# 2   Company 1V
# 3   Company 1U
# 4   Company 1T

# %%
# Retrieve info on updated data set
seg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
#  #   Column                                                                                                                                                                                                                                                                                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                                                                                                                                        --------------  -----
#  0   Legal Compliance: Does your organization have a written non-discrimination or equal employment opportunity policy that  applies to all employees globally and which specifically references "race", "ethnicity", "religion", "socio-economic status", "sexual orientation" and "gender identity" that is distributed to employees through a handbook or other publicly-available place and included in all job descriptions?  24 non-null     int64
#  1   Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims?                                                                                                                                                                                                                                                                                                                 24 non-null     object
#  2   Legal Compliance: Does your organization have any litigation regarding harassment claims?                                                                                                                                                                                                                                                                                                                                     24 non-null     object
#  3   Legal Compliance: Do employees have a collective bargaining agreement?                                                                                                                                                                                                                                                                                                                                                        24 non-null     int64
#  4   Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?                                                                                                                                                                                                                                                                                      24 non-null     object
#  5   Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?                                                                                                                                                                                                                                                                                                  24 non-null     object
#  6   Organization                                                                                                                                                                                                                                                                                                                                                                                                                  24 non-null     object
# dtypes: int64(2), object(5)
# memory usage: 1.4+ KB

# %%
# Describe the updated numerical columns of the data set
seg.describe()
# Out:
#        Legal Compliance: Does your organization have a written non-discrimination or equal employment opportunity policy that  applies to all employees globally and which specifically references "race", "ethnicity", "religion", "socio-economic status", "sexual orientation" and "gender identity" that is distributed to employees through a handbook or other publicly-available place and included in all job descriptions?  \
# count                                          24.000000
# mean                                            0.958333
# std                                             0.204124
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             1.000000
# max                                             1.000000
#
#        Legal Compliance: Do employees have a collective bargaining agreement?
# count                                          24.000000
# mean                                            0.083333
# std                                             0.282330
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000

# %%
# Description of non-numerical columns
seg.describe(include=np.object)
# Out:
#         Legal Compliance: Does your organization have any litigation pending regarding discrimination or EEOC claims?   \
# count                                                24.0
# unique                                                3.0
# top                                                   0.0
# freq                                                 20.0
#
#         Legal Compliance: Does your organization have any litigation regarding harassment claims?   \
# count                                                24.0
# unique                                                3.0
# top                                                   0.0
# freq                                                 21.0
#
#         Legal Compliance: Has your organization eliminated the use of non-disclosure agreements in settling harassment or discrimination claims?  \
# count                                                24.0
# unique                                                3.0
# top                                                   0.0
# freq                                                 17.0
#
#         Legal Compliance: Has your organization eliminated forced mediation requirements from all employee contracts and agreements?  \
# count                                                24.0
# unique                                                3.0
# top                                                   0.0
# freq                                                 14.0
#
#        Organization
# count            24
# unique           24
# top      Company 1T
# freq              1

# %%
# Describe the properties of the table usuing numPy or pandas
# Type of seg
type(seg)
# Out:
# pandas.core.frame.DataFrame

# %%
# Number of rows & columns 
seg.shape
# Out:
# (24, 7)

# %%
# converting to CSV file
seg.to_csv("LegalUpdatedData.csv")
