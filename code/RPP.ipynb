# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data_original/24_Recruitment_compensation_anon.csv")

#move company name & benchmark to the front 
second_col = df.pop('benchmark_group')
df.insert(0, 'benchmark_group', second_col)

first_col = df.pop('Organization')
df.insert(0, 'org', first_col)

# remove columns not on topic
df = df.loc[:, :'Recruitment, Promotion & Pipeline: Before we move to the next section, is there anything else you want to tell us about how your organization tracks, reports on or is working to improve its recruitment, promotion and pipeline development?']

# %%
#Renaming some of the columns to be shorter
df.rename(columns={
        'org':'Organization',
        'benchmark_group':"Benchmark_Group",
        'Recruitment, Promotion & Pipeline:  Has your organization performed an organization-wide review to identify teams that have no or low gender diversity (ie - "the lonely only" - one woman, one female of color, one LGBTQ-identifying person, one woman who is differently-abled)?  ':'Q1',
       'Recruitment, Promotion & Pipeline:  If a review has been conducted, what have been the results?\n':"Q2",
       'Recruitment, Promotion & Pipeline: Have you designed and implemented a recruitment process to eliminate gender equity bias?  \n':'Q3',
       'Statement about gender equity goals in recruitment on all job postings':'Q4_A',
       'Process in-place (with designated and trained teammates or usage of technology) to review and revise job descriptions prior to posting to ensure gender-biased language is eliminated':'Q4_B',
       'Move toward skills-based competencies and growth mindsets and away from focus on certain schools, prior experiences':'Q4_C',
       'Requirement to post jobs on a diverse group of job boards, recruiting firms, etc to ensure opportunities are accessible to a diverse candidate pool':'Q4_D',
       'Blind resume review and blind auditions (as applicable)':'Q4_E',
       'Training for HR and all hiring managers on how to identify and reduce gender equity biases throughout the recruitment process':'Q4_F',
       'Oversight and support by trained HR or other designated-internal teams to ensure unbiased recruitment process':'Q4_G',
       'Oversight by a third-party entity to identify and reduce bias from recruitment process':'Q4_H',
       'Other':'Q4_I',
       'Recruitment, Promotion & Pipeline:  Have gender diverse numeric targets been established - at all steps in the recruitment process -  to ensure a diverse slate of candidates?\n':'Q5',
       'Recruitment, Promotion & Pipeline:  If gender diverse numeric targets have been in place for at least 12 months, have those targets been met?':'Q6',
       'Recruitment, Promotion & Pipeline:  Does your organization on-board new employees using cohorts designed to avoid "one-ness" (only woman, only person of color)?':'Q7',
       'Recruitment, Promotion & Pipeline:  Has your organization implemented a performance review program designed to eliminate gender bias?':'Q8',
       'Recruitment, Promotion & Pipeline:  Have all managers received training, that includes an anti-bias component, on how to implement unbiased gender equity performance reviews? ':'Q9',
       'Recruitment, Promotion & Pipeline:  Do you track success rate of managers of entry-level women to see that women and men are all getting promoted at equal rates from entry level?':'Q10',
       'Recruitment, Promotion & Pipeline:  Are results tracked to determine whether gender bias has been reduced or eliminated from performance reviews?':'Q11',
       'Recruitment, Promotion & Pipeline:  Tell us more about how your organization has tracked performance review results.':'Q12',
       '% of Workers promoted':'Q13_A',
       '% Promoted Workers who identify as Women':'Q13_B',
       'Women who identify as Black or African American':'Q13_C_A',
       'Women who identify as Latina':'Q13_C_B', 
       'Women who identify as Asian':'Q13_C_C',
       'Women who identify as Native American/Alaskan/Pacific Islander':'Q13_C_D',
       'Women who identify as Mixed Race':'Q13_C_E',
       'Women who identify as White/Caucasian':'Q13_C_F',
       'Women who identify as Disabled':'Q13_C_G',
       'Women who identify as LGBTQ':'Q13_C_H',
       'Persons who identify as gender non-binary':'Q13_C_I',
       'None':'Q13_C_J',
       'Give us feedback - how challenging is it to provide internal promotion details for your workforce to the degree asked above?':'Q13_D',
       'Recruitment, Promotion & Pipeline:  If your organization had targets for internal promotion of candidates reflecting gender equity goals, did you meet your goals?':'Q14',
       'Recruitment, Promotion & Pipeline:  Does your organization have a program to retain and promote gender diverse entry and mid-level workers through training, development and other professional development opportunities?':'Q15',
       'Recruitment, Promotion & Pipeline:  If you responded yes or in development, tell us more about the  program to retain and promote gender diverse entry and mid-level workers through training, development and other professional development opportunities.':'Q16',
       'Recruitment, Promotion & Pipeline:  What % of gender diverse workers participated in these types of programs during the last 12 months?':'Q17',
       'Recruitment, Promotion & Pipeline:  During the last 12 months, were participants in these programs promoted at the same or higher rates than all employees across the organization?{{field:70ab1a1c-026b-427f-9511-faed18c9e883}}':'Q18',
       'Recruitment, Promotion & Pipeline:  What % of training and development budget is allocated toward the gender diverse pipeline development programs covered in the questions above?\n':'Q19',
       'At the secondary or tertiary education level':'Q20_A',
       'At the on-ramping/workforce re-entry level for mid-career women':'Q20_B',
       'No':'Q20_C',
       'Other.1':'Q20_D',
       'Recruitment, Promotion & Pipeline:  During the last 12 months, what percentage of participants in these programs have been hired into a full-time role?':'Q21',
       'Recruitment, Promotion & Pipeline: Before we move to the next section, is there anything else you want to tell us about how your organization tracks, reports on or is working to improve its recruitment, promotion and pipeline development?':'Q22'
       },inplace=True)

# %%
df.drop(columns=['Q13_D','Q12','Q22'],inplace=True)
df.columns
# Out:
# Index(['Organization', 'Benchmark_Group', 'Q1', 'Q2', 'Q3', 'Q4_A', 'Q4_B',
#        'Q4_C', 'Q4_D', 'Q4_E', 'Q4_F', 'Q4_G', 'Q4_H', 'Q4_I', 'Q5', 'Q6',
#        'Q7', 'Q8', 'Q9', 'Q10', 'Q11', 'Q13_A', 'Q13_B', 'Q13_C_A', 'Q13_C_B',
#        'Q13_C_C', 'Q13_C_D', 'Q13_C_E', 'Q13_C_F', 'Q13_C_G', 'Q13_C_H',
#        'Q13_C_I', 'Q13_C_J', 'Q14', 'Q15', 'Q16', 'Q17', 'Q18', 'Q19', 'Q20_A',
#        'Q20_B', 'Q20_C', 'Q20_D', 'Q21'],
#       dtype='object')

# %%
df.loc[df['Q1'] == 'No', 'Q2'] = "N/A - No review conducted yet"
df.loc[df['Q1'] == 'In progress', 'Q2'] = "N/A - No review conducted yet"
#df[["Q1","Q2"]]

# %%
df[['Q3','Q4_A','Q4_B','Q4_C','Q4_D']]
# Out:
#                                                 Q3  \
# 0        Process has been designed and implemented
# 1        Process has been designed and implemented
# 2   Process has been designed, not yet implemented
# 3   Process has been designed, not yet implemented
# 4                 No process has been designed yet
# 5                 No process has been designed yet
# 6                 No process has been designed yet
# 7        Process has been designed and implemented
# 8                 No process has been designed yet
# 9        Process has been designed and implemented
# 10                No process has been designed yet
# 11                No process has been designed yet
# 12  Process has been designed, not yet implemented
# 13                No process has been designed yet
# 14                No process has been designed yet
# 15       Process has been designed and implemented
# 16       Process has been designed and implemented
# ...

# %%
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_A'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_B'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_C'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_D'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_E'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_F'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_G'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_H'] = "N/A"
df.loc[df['Q3'] == 'No process has been designed yet', 'Q4_I'] = "N/A"
#df[['Organization','Q3','Q4_A','Q4_B','Q4_C','Q4_D','Q4_E','Q4_F','Q4_G','Q4_H','Q4_I']]

# create column for no response to question 4
df["Q4_J"] = np.nan
df.loc[df["Organization"].isin(["Company 1V"]),"Q4_J"] = "No Response"
df[['Organization','Q3','Q4_A','Q4_B','Q4_C','Q4_D','Q4_E','Q4_F','Q4_G','Q4_H','Q4_I','Q4_J']]
# Out:
#    Organization                                              Q3  \
# 0    Company 1X       Process has been designed and implemented
# 1    Company 1W       Process has been designed and implemented
# 2    Company 1V  Process has been designed, not yet implemented
# 3    Company 1U  Process has been designed, not yet implemented
# 4    Company 1T                No process has been designed yet
# 5    Company 1S                No process has been designed yet
# 6    Company 1R                No process has been designed yet
# 7    Company 1Q       Process has been designed and implemented
# 8    Company 1P                No process has been designed yet
# 9    Company 1O       Process has been designed and implemented
# 10   Company 1N                No process has been designed yet
# 11   Company 1M                No process has been designed yet
# 12   Company 1L  Process has been designed, not yet implemented
# 13   Company 1K                No process has been designed yet
# ...

# %%
df.loc[df['Q5'] == 'No', 'Q6'] = "N/A - No targets set"
df.loc[df['Q5'] == 'In progress', 'Q6'] = "N/A - No targets set"
df[['Organization','Q5','Q6']]
# Out:
#    Organization           Q5                                           Q6
# 0    Company 1X  In progress                         N/A - No targets set
# 1    Company 1W  In progress                         N/A - No targets set
# 2    Company 1V  In progress                         N/A - No targets set
# 3    Company 1U           No                         N/A - No targets set
# 4    Company 1T           No                         N/A - No targets set
# 5    Company 1S           No                         N/A - No targets set
# 6    Company 1R           No                         N/A - No targets set
# 7    Company 1Q           No                         N/A - No targets set
# 8    Company 1P           No                         N/A - No targets set
# 9    Company 1O          Yes  N/A - Plan in place for less than 12 months
# 10   Company 1N           No                         N/A - No targets set
# 11   Company 1M           No                         N/A - No targets set
# ...

# %%
df['Q9'] = df['Q9'].fillna("No response")
df[['Organization','Q9']]
# Out:
#    Organization           Q9
# 0    Company 1X  In progress
# 1    Company 1W           No
# 2    Company 1V  In progress
# 3    Company 1U           No
# 4    Company 1T           No
# 5    Company 1S           No
# 6    Company 1R  In progress
# 7    Company 1Q           No
# 8    Company 1P           No
# 9    Company 1O  In progress
# 10   Company 1N           No
# 11   Company 1M  In progress
# 12   Company 1L           No
# 13   Company 1K           No
# 14   Company 1J          Yes
# 15   Company 1I          Yes
# 16   Company 1H  In progress
# 17   Company 1G           No
# 18   Company 1F  In progress
# 19   Company 1E  In progress
# 20   Company 1D           No
# 21   Company 1C           No
# 22   Company 1B  In progress
# 23   Company 1A  No response

# %%
df['Q11'] = df['Q11'].fillna("No response")
df[['Organization','Q11']]
# Out:
#    Organization                                                Q11
# 0    Company 1X  N/A - No anti-bias performance review plan in ...
# 1    Company 1W  N/A - No anti-bias performance review plan in ...
# 2    Company 1V  N/A - No anti-bias performance review plan in ...
# 3    Company 1U                                        No response
# 4    Company 1T  N/A - No anti-bias performance review plan in ...
# 5    Company 1S  N/A - No anti-bias performance review plan in ...
# 6    Company 1R  N/A - No anti-bias performance review plan in ...
# 7    Company 1Q  N/A - No anti-bias performance review plan in ...
# 8    Company 1P  N/A - No anti-bias performance review plan in ...
# 9    Company 1O  N/A - No anti-bias performance review plan in ...
# 10   Company 1N  N/A - No anti-bias performance review plan in ...
# 11   Company 1M  N/A - No anti-bias performance review plan in ...
# 12   Company 1L  N/A - No anti-bias performance review plan in ...
# ...

# %%
df.loc[df['Q15'] == 'No', 'Q16'] = "N/A"
df.loc[df['Q15'] == 'No', 'Q17'] = "N/A"
df.loc[df['Q15'] == 'No', 'Q18'] = "N/A"
df.loc[df['Q15'] == 'No', 'Q19'] = "N/A"

df[['Organization','Q15','Q16','Q17','Q18','Q19']]
# Out:
#    Organization             Q15  \
# 0    Company 1X              No
# 1    Company 1W  In development
# 2    Company 1V  In development
# 3    Company 1U              No
# 4    Company 1T              No
# 5    Company 1S              No
# 6    Company 1R  In development
# 7    Company 1Q              No
# 8    Company 1P              No
# 9    Company 1O              No
# 10   Company 1N              No
# 11   Company 1M  In development
# 12   Company 1L             Yes
# 13   Company 1K  In development
# 14   Company 1J              No
# 15   Company 1I             Yes
# 16   Company 1H              No
# 17   Company 1G              No
# 18   Company 1F  In development
# 19   Company 1E  In development
# 20   Company 1D              No
# 21   Company 1C              No
# 22   Company 1B              No
# 23   Company 1A  In development
#
#                                                   Q16  Q17  Q18  Q19
# 0                                                 N/A  N/A  N/A  N/A
# ...

# %%
df["Q20_E"] = np.nan
df.loc[df["Organization"].isin(["Company 1W",'"Company 1W"']),"Q20_E"] = "No response"
df.loc[df['Q20_C'] == 'No', 'Q21'] = "N/A"
df['Q21'] = df['Q21'].fillna("No response")
df[['Organization','Q20_A','Q20_B','Q20_C','Q20_D','Q20_E','Q21']]
# Out:
#    Organization                                         Q20_A  \
# 0    Company 1X  At the secondary or tertiary education level
# 1    Company 1W                                           NaN
# 2    Company 1V                                           NaN
# 3    Company 1U  At the secondary or tertiary education level
# 4    Company 1T                                           NaN
# 5    Company 1S                                           NaN
# 6    Company 1R  At the secondary or tertiary education level
# 7    Company 1Q                                           NaN
# 8    Company 1P                                           NaN
# 9    Company 1O  At the secondary or tertiary education level
# 10   Company 1N                                           NaN
# 11   Company 1M                                           NaN
# 12   Company 1L  At the secondary or tertiary education level
# 13   Company 1K                                           NaN
# ...

# %%
#Print df one more time to double check
df
# Out:
#    Organization Benchmark_Group           Q1  \
# 0    Company 1X      Technology          Yes
# 1    Company 1W       NonProfit  In progress
# 2    Company 1V         Finance           No
# 3    Company 1U         Finance          Yes
# 4    Company 1T      Technology           No
# 5    Company 1S      Technology           No
# 6    Company 1R      Technology          Yes
# 7    Company 1Q         Finance  In progress
# 8    Company 1P             NaN  In progress
# 9    Company 1O      Technology  In progress
# 10   Company 1N      Technology          Yes
# 11   Company 1M             NaN          Yes
# 12   Company 1L       NonProfit          Yes
# 13   Company 1K       NonProfit           No
# 14   Company 1J         Finance           No
# 15   Company 1I       NonProfit          Yes
# 16   Company 1H      Technology  In progress
# 17   Company 1G             NaN          Yes
# 18   Company 1F         Finance           No
# 19   Company 1E       NonProfit  In progress
# ...

# %%
#Write out to csv
df.to_csv("Recruitment_clean_final.csv")
