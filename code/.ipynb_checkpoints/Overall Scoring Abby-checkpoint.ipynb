# %% [markdown]
# # Data Cleaning for Gender IDEAL

# %% [markdown]
# Before committing, please re-run the kernel with clear any output to avoid any merge issues with jupyter and github.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
#import altair as alt

pd.set_option("max_columns", None) # show all cols
pd.set_option('max_colwidth', None) # show full width of showing cols
pd.set_option("expand_frame_repr", False) # print cols side by side as it's supposed to be

# %% [markdown]
# Leadership Demographics Category: Scoring

# %%
dfl = pd.read_csv("C:/Users/Admin/Desktop/gender-ideal-main/data_clean/leaderdem_clean.csv", index_col=0)
dfl.fillna('NaN')
dfl
# Out:
#    Organization review_status  \
# 0    Company 1X            No
# 1    Company 1W           Yes
# 2    Company 1V            No
# 3    Company 1U            No
# 4    Company 1T            No
# 5    Company 1S            No
# 6    Company 1R            No
# 7    Company 1Q            No
# 8    Company 1P            No
# 9    Company 1O           Yes
# 10   Company 1N            No
# 11   Company 1M           Yes
# 12   Company 1L           Yes
# 13   Company 1K           Yes
# 14   Company 1J   In progress
# 15   Company 1I            No
# 16   Company 1H            No
# 17   Company 1G            No
# 18   Company 1F            No
# 19   Company 1E            No
# 20   Company 1D            No
# 21   Company 1C            No
# 22   Company 1B            No
# 23   Company 1A   In progress
#
#                                  proportion_local_div           3A  \
# 0                                                 NaN       1481.0
# 1   Minimal to no disparities (ie - the differenti...          6.0
# 2                                                 NaN         37.0
# 3                                                 NaN         56.0
# 4                                                 NaN        181.0
# 5                                                 NaN       1347.0
# 6                                                 NaN         56.0
# 7                                                 NaN        332.0
# 8                                                 NaN        131.0
# 9   Significant disparities (ie - one or more grou...         90.0
# 10                                                NaN         78.0
# 11  Significant disparities (ie - one or more grou...  No Response
# 12  Significant disparities (ie - one or more grou...         12.0
# 13  Modest disparities (ie - the differential betw...         42.0
# 14  Minimal to no disparities (ie - the differenti...       1105.0
# 15                                                NaN         57.0
# 16                                                NaN         55.0
# 17                                                NaN        269.0
# 18                                                NaN          7.0
# 19                                                NaN         83.0
# 20                                                NaN         35.0
# 21                                                NaN         30.0
# 22                                                NaN        216.0
# 23  Minimal to no disparities (ie - the differenti...          8.0
#
#              3B           3C           3D           3E           3F  \
# 0          34.0          6.0          4.0         22.0          1.0
# 1         100.0         33.0         66.0         16.0          0.0
# 2          15.0  No Response  No Response  No Response  No Response
# 3          39.0          2.0          9.0          4.0          0.0
# 4          50.0          6.0          7.0          5.0          0.0
# 5          69.0          4.0         12.0          6.0          1.0
# 6          37.0          2.0          2.0          4.0          0.0
# 7          49.0          5.0          3.0          7.0          0.0
# 8          50.0          4.0          1.0          7.0          0.0
# 9          48.0          6.0          2.0          8.0          0.0
# 10         36.0          4.0          7.0         36.0          0.0
# 11  No Response  No Response  No Response  No Response  No Response
# 12         71.0         30.0  No Response  No Response  No Response
# 13         95.0         35.0  No Response  No Response  No Response
# 14         66.0         20.0          0.0          0.0          0.0
# 15         73.0          5.0          3.0          5.0          0.0
# 16         90.0         10.0         10.0          5.0  No Response
# 17         40.0          3.0          4.0          6.0          1.0
# 18         43.0          0.0          0.0         33.0          0.0
# 19         70.0          9.0         18.0          4.0  No Response
# 3                   NaN   No                N/A - No targets set
# 4                   NaN   No                N/A - No targets set
# 5                   NaN  NaN                         No Response
# 6                   NaN   No                N/A - No targets set
# 7                   NaN   No                N/A - No targets set
# 8                   NaN   No                N/A - No targets set
# 9                   NaN  NaN  Nearing goals (66-99% targets met)
# 10                  NaN   No                N/A - No targets set
# 11                  NaN   No                N/A - No targets set
# 12                  NaN   No                N/A - No targets set
# 13                  NaN  NaN                N/A - No targets set
# 14                  NaN   No                N/A - No targets set
# 15                  NaN  NaN  Nearing goals (66-99% targets met)
# 16                  NaN   No                N/A - No targets set
# 17                  NaN   No                N/A - No targets set
# 18                  NaN  NaN                         No Response
# 19  Internal Promotions  NaN                         No Response
# 20                  NaN  NaN                         No Response
# 21                  NaN  NaN                         No Response
# 22                  NaN  NaN                         No Response
# 23  Internal Promotions  NaN                         No Response
#
#    benchmark_group       number_of_employees     number_of_years  \
# 0       Technology      1000-4,999 Employees          5-14 years
# 1        NonProfit  Fewer than 100 Employees    15 or more years
# 2          Finance  Fewer than 100 Employees          5-14 years
# 3          Finance  Fewer than 100 Employees    15 or more years
# 4       Technology         100-249 Employees          5-14 years
# 5       Technology      1000-4,999 Employees  Fewer than 5 years
# 6       Technology  Fewer than 100 Employees  Fewer than 5 years
# 7          Finance         250-999 Employees          5-14 years
# 8              NaN         100-249 Employees          5-14 years
# 9       Technology  Fewer than 100 Employees  Fewer than 5 years
# 10      Technology  Fewer than 100 Employees  Fewer than 5 years
# 11             NaN  Fewer than 100 Employees    15 or more years
# 12       NonProfit  Fewer than 100 Employees          5-14 years
# 13       NonProfit  Fewer than 100 Employees    15 or more years
# 14         Finance      1000-4,999 Employees    15 or more years
# 15       NonProfit  Fewer than 100 Employees          5-14 years
# 16      Technology         250-999 Employees          5-14 years
# 17             NaN  Fewer than 100 Employees  Fewer than 5 years
# 18         Finance  Fewer than 100 Employees  Fewer than 5 years
# 19       NonProfit  Fewer than 100 Employees          5-14 years
# 20      Technology  Fewer than 100 Employees          5-14 years
# 21             NaN  Fewer than 100 Employees  Fewer than 5 years
# 22         Finance         100-249 Employees    15 or more years
# 23         Finance  Fewer than 100 Employees          5-14 years
#
#                                             workforce           9H
# 0              At least 80% of employees are Salaried          NaN
# 1   We have a mixed workforce of hourly and salari...          NaN
# 2              At least 80% of employees are Salaried          NaN
# 3              At least 80% of employees are Salaried          NaN
# 4   We have a mixed workforce of hourly and salari...          NaN
# 5   We have a mixed workforce of hourly and salari...          NaN
# 6              At least 80% of employees are Salaried          NaN
# 7              At least 80% of employees are Salaried          NaN
# 8   We have a mixed workforce of hourly and salari...          NaN
# 9              At least 80% of employees are Salaried          NaN
# 10             At least 80% of employees are Salaried          NaN
# 11             At least 80% of employees are Salaried          NaN
# 12  We have a mixed workforce of hourly and salari...          NaN
# 13             At least 80% of employees are Salaried          NaN
# 14  We have a mixed workforce of hourly and salari...          NaN
# 15             At least 80% of employees are Salaried          NaN
# 16  We have a mixed workforce of hourly and salari...          NaN
# 17             At least 80% of employees are Salaried          NaN
# 18             At least 80% of employees are Salaried          NaN
# 19             At least 80% of employees are Salaried          NaN
# 20             At least 80% of employees are Salaried          NaN
# 21               At least 80% of employees are Hourly  No Response
# 22             At least 80% of employees are Salaried  No Response
# 23  We have a mixed workforce of hourly and salari...          NaN

# %%
# Questions 1, 2, 9, and 10 have equal weight of 25% of the Leadership score.
w1 = 0.25
w2 = 0.25
w9 = 0.25
w10 = 0.25
w = [w1, w2, w9, w10]

leader_weight = 7.5

# For each Company row, generate score by weights determined above.
dfl = dfl[['Organization', 'review_status', 'proportion_local_div', '9A', '9B', '9C', '9D', '9E', '9F', '9G', '10']].copy()
dfl

# Function to apply to each row:
def compute_score(row):
    # Q9:
    # No = 0% 
    # In Progress = 50%
    # Yes = 100%
    # No Sum
    
    q1 = row['review_status']
    if q1 == 'No':
        s1 = 0
    elif q1 == 'In progress':
        s1 = 0.5
    elif q1 == 'Yes':
        s1 = 1
    else:
        s1 = 0
        
    # Q2: 
    # Signficant disparities (>10%) = 33%
    # Modest disparities (<=10%) = 66%
    # Minimal to no disparities (<=5%) = 100%
    # No/N/A = 0%
    # No Sum
    
    q2 = row['proportion_local_div']
    if q2 == """Significant disparities
    (ie - one or more groups that represent
    >10% population not represented in our workforce)""":
        s2 = 0.33
    elif q2 == """Modest disparities
    (ie - the differential between our workforce
    and the population across different groups is 10% or less per group)""":
        s2 = 0.66
    elif q2 == """Minimal to no disparities
    (ie - the differential between our workforce 
    and the population across different groups is 5% or less per group)""":
        s2 = 1
    else: # N/A or No
        s2 = 0  

    # Q9:
    # C-Suite = 50%
    # Board/Advisory Bodies = 50%
    # Management = 50%
    # Mentorship Programs = 50%
    # Promotions = 50%
    # N/A or No = 0%
    # Multi-pick/ Responses sum; Cap at 100%"
    s9 = 0
    if row['9A'] == 'C-Suite':
        s9 += 0.5
    if row['9B'] == 'Board/Advisory Bodies':
        s9 += 0.5
    if row['9C'] == 'Senior Management':
        s9 += 0.5
    if row['9D'] == 'Management':
        s9 += 0.5
    if row['9E'] == 'Mentorship Programs':
        s9 += 0.5
    if row['9F'] == 'Internal Promotions':
        s9 += 0.5
    #9G excluded since all responses can only be No or NaN
    if s9 > 1:
        s9 = 1
        
    # Q10:
    # N/A - No targets set = 0%
    # Behind goals (<66% or fewer targets met) = 50%
    # Nearing goals (66-99% targets met) = 100%
    # Goals met = 100%
    # Goals exceeded = 100%
    # No Sum
    
    q10 = row['10']
    if q2 == 'Behind goals (<66% or fewer targets met)':
        s10 = 0.5
    elif q10 == 'Nearing goals (66-99% targets met)' or q10 == 'Goals met' or q10 == 'Goals exceeded': 
        s10 = 1
    else: #no targets set or NaN
        s10 = 0
    
    s = [s1, s2, s9, s10]
    
    #preliminary score
    return sum(map(lambda a, b: a * b, s, w))

dfl.loc[:,'leader_prelim_score'] = dfl.apply(compute_score, axis = 1)
dfl.loc[:,'leader_weighted_score'] = dfl['leader_prelim_score'] * leader_weight

# Reverse indices so that Company 1A is listed first.
dfl.index = dfl.index.values[::-1]
dfl = dfl[::-1]
dfl
# Out:
#    Organization review_status  \
# 0    Company 1A   In progress
# 1    Company 1B            No
# 2    Company 1C            No
# 3    Company 1D            No
# 4    Company 1E            No
# 5    Company 1F            No
# 6    Company 1G            No
# 7    Company 1H            No
# 8    Company 1I            No
# 9    Company 1J   In progress
# 10   Company 1K           Yes
# 11   Company 1L           Yes
# 12   Company 1M           Yes
# 13   Company 1N            No
# 14   Company 1O           Yes
# 15   Company 1P            No
# 16   Company 1Q            No
# 17   Company 1R            No
# 18   Company 1S            No
# 19   Company 1T            No
# 20   Company 1U            No
# 21   Company 1V            No
# 22   Company 1W           Yes
# 23   Company 1X            No
#
#                                  proportion_local_div       9A  \
# 0   Minimal to no disparities (ie - the differenti...  C-Suite
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3                                                 NaN      NaN
# 4                                                 NaN      NaN
# 5                                                 NaN      NaN
# 6                                                 NaN      NaN
# 7                                                 NaN      NaN
# 8                                                 NaN      NaN
# 9   Minimal to no disparities (ie - the differenti...      NaN
# 10  Modest disparities (ie - the differential betw...      NaN
# 11  Significant disparities (ie - one or more grou...      NaN
# 12  Significant disparities (ie - one or more grou...      NaN
# 13                                                NaN      NaN
# 14  Significant disparities (ie - one or more grou...  C-Suite
# 15                                                NaN      NaN
# 16                                                NaN      NaN
# 17                                                NaN      NaN
# 18                                                NaN      NaN
# 19                                                NaN      NaN
# 20                                                NaN      NaN
# 21                                                NaN      NaN
# 22  Minimal to no disparities (ie - the differenti...      NaN
# 23                                                NaN      NaN
#
#                        9B                 9C          9D                   9E  \
# 0   Board/Advisory Bodies  Senior Management  Management  Mentorship Programs
# 1                     NaN                NaN         NaN                  NaN
# 2                     NaN                NaN         NaN                  NaN
# 3   Board/Advisory Bodies                NaN         NaN                  NaN
# 4                     NaN                NaN         NaN                  NaN
# 5                     NaN                NaN  Management                  NaN
# 6                     NaN                NaN         NaN                  NaN
# 7                     NaN                NaN         NaN                  NaN
# 8                     NaN  Senior Management         NaN                  NaN
# 9                     NaN                NaN         NaN                  NaN
# 10                    NaN                NaN         NaN  Mentorship Programs
# 11                    NaN                NaN         NaN                  NaN
# 12                    NaN                NaN         NaN                  NaN
# 13                    NaN                NaN         NaN                  NaN
# 14  Board/Advisory Bodies  Senior Management  Management                  NaN
# 15                    NaN                NaN         NaN                  NaN
# 16                    NaN                NaN         NaN                  NaN
# 17                    NaN                NaN         NaN                  NaN
# 18  Board/Advisory Bodies                NaN         NaN                  NaN
# 19                    NaN                NaN         NaN                  NaN
# 20                    NaN                NaN         NaN                  NaN
# 21                    NaN                NaN         NaN                  NaN
# 22                    NaN                NaN         NaN                  NaN
# 23                    NaN  Senior Management  Management                  NaN
#
#                      9F   9G                                  10  \
# 0   Internal Promotions  NaN                         No Response
# 1                   NaN  NaN                         No Response
# 2                   NaN  NaN                         No Response
# 3                   NaN  NaN                         No Response
# 4   Internal Promotions  NaN                         No Response
# 5                   NaN  NaN                         No Response
# 6                   NaN   No                N/A - No targets set
# 7                   NaN   No                N/A - No targets set
# 8                   NaN  NaN  Nearing goals (66-99% targets met)
# 9                   NaN   No                N/A - No targets set
# 10                  NaN  NaN                N/A - No targets set
# 11                  NaN   No                N/A - No targets set
# 12                  NaN   No                N/A - No targets set
# 13                  NaN   No                N/A - No targets set
# 14                  NaN  NaN  Nearing goals (66-99% targets met)
# 15                  NaN   No                N/A - No targets set
# 16                  NaN   No                N/A - No targets set
# 17                  NaN   No                N/A - No targets set
# 18                  NaN  NaN                         No Response
# 19                  NaN   No                N/A - No targets set
# 20                  NaN   No                N/A - No targets set
# 21                  NaN   No                N/A - No targets set
# 22                  NaN   No                N/A - No targets set
# 23                  NaN  NaN                           Goals met
#
#     leader_prelim_score  leader_weighted_score
# 0                 0.375                 2.8125
# 1                 0.000                 0.0000
# 2                 0.000                 0.0000
# 3                 0.125                 0.9375
# 4                 0.125                 0.9375
# 5                 0.125                 0.9375
# 6                 0.000                 0.0000
# 7                 0.000                 0.0000
# 8                 0.375                 2.8125
# 9                 0.125                 0.9375
# 10                0.375                 2.8125
# 11                0.250                 1.8750
# 12                0.250                 1.8750
# 13                0.000                 0.0000
# 14                0.750                 5.6250
# 15                0.000                 0.0000
# 16                0.000                 0.0000
# 17                0.000                 0.0000
# 18                0.125                 0.9375
# 19                0.000                 0.0000
# 20                0.000                 0.0000
# 21                0.000                 0.0000
# 22                0.250                 1.8750
# 23                0.500                 3.7500

# %%
#Write out to csv
dfl.to_csv("C:/Users/Admin/Desktop/gender-ideal-main/scores/leader_scores_clean.csv")

# %% [markdown]
# Vision Category: Scoring
# ## Vision Weight: UNKNOWN

# %%
dfv = pd.read_csv("C:/Users/Admin/Desktop/gender-ideal-main/data_clean/vision_clean_final.csv", index_col=0)
dfv
# Out:
#    Organization       number_of_employees     number_of_years  \
# 0    Company 1X      1000-4,999 Employees          5-14 years
# 1    Company 1W  Fewer than 100 Employees    15 or more years
# 2    Company 1V  Fewer than 100 Employees          5-14 years
# 3    Company 1U  Fewer than 100 Employees    15 or more years
# 4    Company 1T         100-249 Employees          5-14 years
# 5    Company 1S      1000-4,999 Employees  Fewer than 5 years
# 6    Company 1R  Fewer than 100 Employees  Fewer than 5 years
# 7    Company 1Q         250-999 Employees          5-14 years
# 8    Company 1P         100-249 Employees          5-14 years
# 9    Company 1O  Fewer than 100 Employees  Fewer than 5 years
# 10   Company 1N  Fewer than 100 Employees  Fewer than 5 years
# 11   Company 1M  Fewer than 100 Employees    15 or more years
# 12   Company 1L  Fewer than 100 Employees          5-14 years
# 13   Company 1K  Fewer than 100 Employees    15 or more years
# 14   Company 1J      1000-4,999 Employees    15 or more years
# 15   Company 1I  Fewer than 100 Employees          5-14 years
# 16   Company 1H         250-999 Employees          5-14 years
# 17   Company 1G  Fewer than 100 Employees  Fewer than 5 years
# 18   Company 1F  Fewer than 100 Employees  Fewer than 5 years
# 19   Company 1E  Fewer than 100 Employees          5-14 years
# 20   Company 1D  Fewer than 100 Employees          5-14 years
# 21   Company 1C  Fewer than 100 Employees  Fewer than 5 years
# 22   Company 1B         100-249 Employees    15 or more years
# 23   Company 1A  Fewer than 100 Employees          5-14 years
#
#                                             workforce  \
# 0              At least 80% of employees are Salaried
# 1   We have a mixed workforce of hourly and salari...
# 2              At least 80% of employees are Salaried
# 3              At least 80% of employees are Salaried
# 4   We have a mixed workforce of hourly and salari...
# 5   We have a mixed workforce of hourly and salari...
# 6              At least 80% of employees are Salaried
# 7              At least 80% of employees are Salaried
# 8   We have a mixed workforce of hourly and salari...
# 9              At least 80% of employees are Salaried
# 10             At least 80% of employees are Salaried
# 11             At least 80% of employees are Salaried
# 12  We have a mixed workforce of hourly and salari...
# 13             At least 80% of employees are Salaried
# 14  We have a mixed workforce of hourly and salari...
# 15             At least 80% of employees are Salaried
# 16  We have a mixed workforce of hourly and salari...
# 17             At least 80% of employees are Salaried
# 18             At least 80% of employees are Salaried
# 19             At least 80% of employees are Salaried
# 20             At least 80% of employees are Salaried
# 21               At least 80% of employees are Hourly
# 22             At least 80% of employees are Salaried
# 23  We have a mixed workforce of hourly and salari...
#
#                            Q9_A                                    Q9_B  \
# 0   N/A, No EDI policy in place                                     NaN
# 1   N/A, No EDI policy in place                                     NaN
# 2   N/A, No EDI policy in place                                     NaN
# 3                           NaN  Women and people who identify as women
# 4   N/A, No EDI policy in place                                     NaN
# 5                           NaN  Women and people who identify as women
# 6   N/A, No EDI policy in place                                     NaN
# 7                           NaN  Women and people who identify as women
# 8   N/A, No EDI policy in place                                     NaN
# 9   N/A, No EDI policy in place                                     NaN
# 10  N/A, No EDI policy in place                                     NaN
# 11  N/A, No EDI policy in place                                     NaN
# 12                          NaN                                     NaN
# 13                          NaN  Women and people who identify as women
# 14                          NaN  Women and people who identify as women
# 15  N/A, No EDI policy in place                                     NaN
# 16  N/A, No EDI policy in place                                     NaN
# 17  N/A, No EDI policy in place                                     NaN
# 18  N/A, No EDI policy in place                                     NaN
# 19  N/A, No EDI policy in place                                     NaN
# 20  N/A, No EDI policy in place                                     NaN
# 21                          NaN                                     NaN
# 22                          NaN  Women and people who identify as women
# 23                          NaN  Women and people who identify as women
#
#                Q9_C                                               Q9_D  \
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN  Women of color, including all races and ethnic...
# 4               NaN                                                NaN
# 5   Working mothers  Women of color, including all races and ethnic...
# 6               NaN                                                NaN
# 7   Working mothers  Women of color, including all races and ethnic...
# 8               NaN                                                NaN
# 9               NaN                                                NaN
# 10              NaN                                                NaN
# 11              NaN                                                NaN
# 12              NaN  Women of color, including all races and ethnic...
# 13              NaN                                                NaN
# 14              NaN  Women of color, including all races and ethnic...
# 15              NaN                                                NaN
# 16              NaN                                                NaN
# 17              NaN                                                NaN
# 18              NaN                                                NaN
# 19              NaN                                                NaN
# 20              NaN                                                NaN
# 21              NaN  Women of color, including all races and ethnic...
# 22  Working mothers  Women of color, including all races and ethnic...
# 23  Working mothers  Women of color, including all races and ethnic...
#
#                                Q9_E  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3   Women of all types of abilities
# 4                               NaN
# 5   Women of all types of abilities
# 6                               NaN
# 7   Women of all types of abilities
# 8                               NaN
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12  Women of all types of abilities
# 13                              NaN
# 14  Women of all types of abilities
# 15                              NaN
# 16                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22  Women of all types of abilities
# 23  Women of all types of abilities
#
#                                            Q9_F  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3   Persons of all non-binary gender identities
# 4                                           NaN
# 5   Persons of all non-binary gender identities
# 6                                           NaN
# 7   Persons of all non-binary gender identities
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14  Persons of all non-binary gender identities
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22  Persons of all non-binary gender identities
# 23  Persons of all non-binary gender identities
#
#                                 Q9_G                    Q9_H  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3   Women of all sexual orientations  Women of all religions
# 4                                NaN                     NaN
# 5   Women of all sexual orientations  Women of all religions
# 6                                NaN                     NaN
# 7   Women of all sexual orientations  Women of all religions
# 8                                NaN                     NaN
# 9                                NaN                     NaN
# 10                               NaN                     NaN
# 11                               NaN                     NaN
# 12                               NaN                     NaN
# 13                               NaN                     NaN
# 14  Women of all sexual orientations  Women of all religions
# 15                               NaN                     NaN
# 16                               NaN                     NaN
# 17                               NaN                     NaN
# 18                               NaN                     NaN
# 19                               NaN                     NaN
# 20                               NaN                     NaN
# 21                               NaN                     NaN
# 22  Women of all sexual orientations  Women of all religions
# 23  Women of all sexual orientations  Women of all religions
#
#                                   Q9_I  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3   Women of all socio-economic levels
# 4                                  NaN
# 5   Women of all socio-economic levels
# 6                                  NaN
# 7   Women of all socio-economic levels
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                 NaN
# 15                                 NaN
# 16                                 NaN
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                 NaN
# 22  Women of all socio-economic levels
# 23  Women of all socio-economic levels
#
#                                                 Q10_A  \
# 0   Conducted a demographic analysis of the curren...
# 1                                                 NaN
# 2                                                 NaN
# 3   Conducted a demographic analysis of the curren...
# 4   Conducted a demographic analysis of the curren...
# 5   Conducted a demographic analysis of the curren...
# 6   Conducted a demographic analysis of the curren...
# 7   Conducted a demographic analysis of the curren...
# 8   Conducted a demographic analysis of the curren...
# 9                                                 NaN
# 10  Conducted a demographic analysis of the curren...
# 11  Conducted a demographic analysis of the curren...
# 12  Conducted a demographic analysis of the curren...
# 13  Conducted a demographic analysis of the curren...
# 14  Conducted a demographic analysis of the curren...
# 15  Conducted a demographic analysis of the curren...
# 16  Conducted a demographic analysis of the curren...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  Conducted a demographic analysis of the curren...
# 21                                                NaN
# 22  Conducted a demographic analysis of the curren...
# 23  Conducted a demographic analysis of the curren...
#
#                                                 Q10_B  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Conducted a baseline culture analysis using em...
# 5   Conducted a baseline culture analysis using em...
# 6                                                 NaN
# 7   Conducted a baseline culture analysis using em...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Conducted a baseline culture analysis using em...
# 12                                                NaN
# 13                                                NaN
# 14  Conducted a baseline culture analysis using em...
# 15  Conducted a baseline culture analysis using em...
# 16  Conducted a baseline culture analysis using em...
# 17  Conducted a baseline culture analysis using em...
# 18                                                NaN
# 19                                                NaN
# 20  Conducted a baseline culture analysis using em...
# 21  Conducted a baseline culture analysis using em...
# 22                                                NaN
# 23                                                NaN
#
#                                                 Q10_C  \
# 0   Established goals regarding gender equity for ...
# 1                                                 NaN
# 2   Established goals regarding gender equity for ...
# 3                                                 NaN
# 4                                                 NaN
# 5   Established goals regarding gender equity for ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Established goals regarding gender equity for ...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Established goals regarding gender equity for ...
# 16  Established goals regarding gender equity for ...
# 17                                                NaN
# 18                                                NaN
# 19  Established goals regarding gender equity for ...
# 20                                                NaN
# 21                                                NaN
# 22  Established goals regarding gender equity for ...
# 23                                                NaN
#
#                                                 Q10_D Q10_E  \
# 0                                                 NaN   NaN
# 1                                                 NaN  None
# 2   Developed a timebound roadmap to meet establis...   NaN
# 3                                                 NaN   NaN
# 4                                                 NaN   NaN
# 5   Developed a timebound roadmap to meet establis...   NaN
# 6                                                 NaN   NaN
# 7                                                 NaN   NaN
# 8                                                 NaN   NaN
# 9                                                 NaN   NaN
# 10                                                NaN   NaN
# 11                                                NaN   NaN
# 12                                                NaN   NaN
# 13                                                NaN   NaN
# 14                                                NaN   NaN
# 15  Developed a timebound roadmap to meet establis...   NaN
# 16                                                NaN   NaN
# 17                                                NaN   NaN
# 18                                                NaN  None
# 19                                                NaN   NaN
# 20                                                NaN   NaN
# 21                                                NaN   NaN
# 22                                                NaN   NaN
# 23                                                NaN   NaN
#
#                                                 Q11_A  \
# 0   Dedicated team responsible for establishing an...
# 1                                                 NaN
# 2   Dedicated team responsible for establishing an...
# 3                                                 NaN
# 4                                                 NaN
# 5   Dedicated team responsible for establishing an...
# 6                                                 NaN
# 7   Dedicated team responsible for establishing an...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Dedicated team responsible for establishing an...
# 12                                                NaN
# 13                                                NaN
# 14  Dedicated team responsible for establishing an...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  Dedicated team responsible for establishing an...
# 19  Dedicated team responsible for establishing an...
# 20                                                NaN
# 21                                                NaN
# 22  Dedicated team responsible for establishing an...
# 23                                                NaN
#
#                                               Q11_B  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5   Specific timeline on when targets should be met
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15  Specific timeline on when targets should be met
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
#
#                                                 Q11_C  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Engagement with all staff on targets and their...
# 6                                                 NaN
# 7   Engagement with all staff on targets and their...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  Engagement with all staff on targets and their...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  Engagement with all staff on targets and their...
# 16  Engagement with all staff on targets and their...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Engagement with all staff on targets and their...
# 22                                                NaN
# 23  Engagement with all staff on targets and their...
#
#                                                 Q11_D Q11_E  \
# 0                                                 NaN   NaN
# 1                                                 NaN  None
# 2                                                 NaN   NaN
# 3                                                 NaN  None
# 4                                                 NaN  None
# 5   Training of all employees who have a direct im...   NaN
# 6                                                 NaN   NaN
# 7                                                 NaN   NaN
# 8                                                 NaN  None
# 9                                                 NaN  None
# 10                                                NaN  None
# 11  Training of all employees who have a direct im...   NaN
# 12                                                NaN  None
# 13                                                NaN   NaN
# 14                                                NaN   NaN
# 15                                                NaN   NaN
# 16                                                NaN   NaN
# 17                                                NaN   NaN
# 18                                                NaN   NaN
# 19                                                NaN   NaN
# 20                                                NaN  None
# 21  Training of all employees who have a direct im...   NaN
# 22                                                NaN   NaN
# 23                                                NaN   NaN
#
#                                                 Q11_F                Q12_A  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6                                                 NaN                  NaN
# 7                                                 NaN                  NaN
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10                                                NaN                  NaN
# 11                                                NaN                  NaN
# 12                                                NaN                  NaN
# 13                                                NaN                  NaN
# 14                                                NaN                  NaN
# 15  Hired an external DEI consultant to help evalu...  All Hiring Managers
# 16                                                NaN                  NaN
# 17  Engagement with SOME staff on targets and thei...                  NaN
# 18                                                NaN                  NaN
# 19                                                NaN                  NaN
# 20                                                NaN                  NaN
# 21                                                NaN                  NaN
# 22                                                NaN  All Hiring Managers
# 23                                                NaN                  NaN
#
#                    Q12_B                  Q12_C    Q12_D Q12_E  \
# 0                    NaN                    NaN      NaN  None
# 1                    NaN                    NaN      NaN  None
# 2                    NaN                    NaN      NaN  None
# 3                    NaN                    NaN      NaN  None
# 4                    NaN                    NaN      NaN  None
# 5                    NaN                    NaN      NaN  None
# 6                    NaN                    NaN      NaN  None
# 7                    NaN                    NaN      NaN   NaN
# 8                    NaN                    NaN      NaN  None
# 9                    NaN                    NaN      NaN  None
# 10                   NaN                    NaN      NaN   NaN
# 11                   NaN                    NaN      NaN  None
# 12                   NaN                    NaN      NaN  None
# 13                   NaN                    NaN      NaN  None
# 14                   NaN                    NaN      NaN  None
# 15                   NaN  All Senior Management  C-Suite   NaN
# 16                   NaN                    NaN      NaN  None
# 17                   NaN                    NaN      NaN  None
# 18                   NaN                    NaN      NaN  None
# 19  Human Resources Dept                    NaN      NaN   NaN
# 20                   NaN                    NaN      NaN  None
# 21                   NaN                    NaN      NaN  None
# 22  Human Resources Dept                    NaN      NaN   NaN
# 23                   NaN                    NaN      NaN  None
#
#                                                 Q12_F Q13_A  \
# 0                                                 NaN    No
# 1                                                 NaN   NaN
# 2                                                 NaN   NaN
# 3                                                 NaN    No
# 4                                                 NaN   NaN
# 5                                                 NaN   NaN
# 6                                                 NaN   NaN
# 7                                                 NaN   NaN
# 8                                                 NaN    No
# 9                                                 NaN   NaN
# 10  There are no goals or specific targets but we ...    No
# 11                                                NaN    No
# 12                                                NaN    No
# 13                                                NaN   NaN
# 14                                                NaN   NaN
# 15                                                NaN   NaN
# 16                                                NaN    No
# 17                                                NaN   NaN
# 18                                                NaN    No
# 19                                                NaN    No
# 20                                                NaN    No
# 21                                                NaN    No
# 22                                                NaN    No
# 23                                                NaN   NaN
#
#                                             Q13_B  \
# 0                                             NaN
# 1   Yes, internal statement made to all employees
# 2   Yes, internal statement made to all employees
# 3                                             NaN
# 4   Yes, internal statement made to all employees
# 5                                             NaN
# 6   Yes, internal statement made to all employees
# 7   Yes, internal statement made to all employees
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15  Yes, internal statement made to all employees
# 16                                            NaN
# 17  Yes, internal statement made to all employees
# 18                                            NaN
# 19                                            NaN
# 20                                            NaN
# 21                                            NaN
# 22                                            NaN
# 23  Yes, internal statement made to all employees
#
#                                                 Q13_C  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Yes, official public/external statement made a...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Yes, official public/external statement made a...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Yes, official public/external statement made a...
# 14  Yes, official public/external statement made a...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  Yes, official public/external statement made a...
#
#                                                   Q14  \
# 0                          No EDI report is published
# 1                          No EDI report is published
# 2                          No EDI report is published
# 3                          No EDI report is published
# 4                          No EDI report is published
# 5                          No EDI report is published
# 6                          No EDI report is published
# 7                          No EDI report is published
# 8                          No EDI report is published
# 9                          No EDI report is published
# 10                         No EDI report is published
# 11                         No EDI report is published
# 12                         No EDI report is published
# 13                         No EDI report is published
# 14                         No EDI report is published
# 15                         No EDI report is published
# 16                                              Other
# 17                         No EDI report is published
# 18  Publish an annual EDI report that includes per...
# 19                         No EDI report is published
# 20                         No EDI report is published
# 21                                              Other
# 22                         No EDI report is published
# 23                         No EDI report is published
#
#                                             Q14_Other  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16             Internal report of demographic metrics
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Prepare report on work on EDI, no gender perfo...
# 22                                                NaN
# 23                                                NaN
#
#                                  Q15_A                           Q15_B  Q15_C  \
# 0                                  NaN  HRC's Corporate Equality Index    NaN
# 1                                  NaN                             NaN    NaN
# 2                                  NaN                             NaN    NaN
# 3                                  NaN                             NaN    NaN
# 4                                  NaN                             NaN    NaN
# 5                                  NaN                             NaN    NaN
# 6                                  NaN                             NaN    NaN
# 7                                  NaN                             NaN    NaN
# 8                                  NaN                             NaN    NaN
# 9                                  NaN                             NaN    NaN
# 10                                 NaN                             NaN    NaN
# 11                                 NaN                             NaN    NaN
# 12                                 NaN                             NaN    NaN
# 13                                 NaN                             NaN    NaN
# 14                                 NaN                             NaN    NaN
# 15                                 NaN                             NaN    NaN
# 16                                 NaN                             NaN    NaN
# 17                                 NaN                             NaN    NaN
# 18                                 NaN                             NaN    NaN
# 19                                 NaN                             NaN    NaN
# 20                                 NaN                             NaN    NaN
# 21                                 NaN                             NaN    NaN
# 22                                 NaN                             NaN    NaN
# 23  Womens Empowerment Principles (UN)                             NaN    NaN
#
#     Q15_D                  Q15_E Q15_F              Q15_G benchmark_group  \
# 0     NaN                    NaN   NaN                NaN      Technology
# 1     NaN                    NaN  None                NaN       NonProfit
# 2     NaN                    NaN  None                NaN         Finance
# 3     NaN                    NaN  None                NaN         Finance
# 4     NaN                    NaN  None                NaN      Technology
# 5     NaN  Gender Equality Index   NaN                NaN      Technology
# 6     NaN                    NaN  None                NaN      Technology
# 7     NaN                    NaN  None                NaN         Finance
# 8     NaN                    NaN  None                NaN             NaN
# 9     NaN                    NaN  None                NaN      Technology
# 10    NaN                    NaN  None                NaN      Technology
# 11    NaN                    NaN  None                NaN             NaN
# 12    NaN                    NaN  None                NaN       NonProfit
# 13    NaN                    NaN  None                NaN       NonProfit
# 14    NaN                    NaN  None                NaN         Finance
# 15    NaN                    NaN  None                NaN       NonProfit
# 16    NaN                    NaN  None                NaN      Technology
# 17    NaN                    NaN  None                NaN             NaN
# 18    NaN                    NaN  None                NaN         Finance
# 19    NaN                    NaN  None                NaN       NonProfit
# 20    NaN                    NaN  None                NaN      Technology
# 21    NaN                    NaN  None                NaN             NaN
# 22    NaN                    NaN  None                NaN         Finance
# 23    NaN                    NaN   NaN  Gender Equity Now         Finance
#
#           Q11_G        Q12_G
# 0           NaN          NaN
# 1           NaN          NaN
# 2           NaN          NaN
# 3           NaN          NaN
# 4           NaN          NaN
# 5           NaN          NaN
# 6   No Response          NaN
# 7           NaN  No Response
# 8           NaN          NaN
# 9           NaN          NaN
# 10          NaN          NaN
# 11          NaN          NaN
# 12          NaN          NaN
# 13  No Response          NaN
# 14          NaN          NaN
# 15          NaN          NaN
# 16          NaN          NaN
# 17          NaN          NaN
# 18          NaN          NaN
# 19          NaN          NaN
# 20          NaN          NaN
# 21          NaN          NaN
# 22          NaN          NaN
# 23          NaN          NaN

# %%
# Questions 1, 2, 9, and 10 have equal weight of 25% of the Leadership score.
w9 = 0.10
w10 = 0.15
w11 = 0.20
w12 = 0.25
w13 = 0.20
w14 = 0.10
w = [w9, w10, w11, w12, w13, w14]

vision_weight = 1 # Fill in with proper point weight here.

# For each Company row, generate score by weights determined above.
dfv = dfv[['Q9_A', 'Q9_B', 'Q9_C', 'Q9_D', 'Q9_E', 'Q9_F', 'Q9_G', 'Q9_H', 'Q9_I', 'Q10_A', 'Q10_B', 'Q10_C', 'Q10_D', 'Q10_E', 
           'Q11_A', 'Q11_B', 'Q11_C', 'Q11_D', 'Q11_E', 'Q11_F', 'Q11_G', 'Q12_A', 'Q12_B', 'Q12_C', 'Q12_D', 'Q12_E', 'Q12_F', 'Q12_G',
           'Q13_A', 'Q13_B', 'Q13_C', 'Q14', 'Q14_Other', 'Q15_A', 'Q15_B', 'Q15_C', 'Q15_D', 'Q15_E', 'Q15_F', 'Q15_G']].copy()
dfv

# Function to apply to each row:
def compute_score(row):
    
    # Q9:
    # Choose all that apply: Sum
    
    s9 = 0
    categories = 9
    point9 = 0.2
    
    q9a = row['Q9_A']
    q9b = row['Q9_B']
    q9c = row['Q9_C']
    q9d = row['Q9_D']
    q9e = row['Q9_E']
    q9f = row['Q9_F']
    q9g = row['Q9_G']
    q9h = row['Q9_H']
    q9i = row['Q9_I']
    
    if q9a == "N/A, No EDI statement in place" or q9a == "NaN":
        s9 += 0
    if q9b == "Women and people who identify as women":
        q9 += point9
    if q9c == "Working mothers":
        q9 += point9
    if q9d == "Women of color, including all races and ethnicities"
        q9 += point9
    if q9e == "Women of all types of abilities":
        q9 += point9
    if q9f == "Persons of all non-binary gender identities": 
        q9 += point9
    if q9g == "Women of all sexual orientations":
        q9 += point9
    if q9h == "Women of all religions":
        q9 += point9
    if q9i == "Women of all socio-economic levels":
        q9 += point9
        
    # Q10: 
    # Conducted a demographic analysis of the current workforce = 20%
    # Conducted a baseline culture analysis using employee feedback to identify gaps = 20%
    # Shared performance on these analyses with all people managers = 20% (?)
    # Established goals regarding gender equity for the whole organization = 20%
    # Developed a timebound roadmap to meet established goals = 20%
    # None = 0% (q10_e excluded, since responses are either NaN or None)
    # Q11_e, _f: description / other / None, do not include in score
    # Sum, no cap

    s10 = 0
    point10 = 0.2
    
    q10a = row['Q10_A']
    q10b = row['Q10_B']
    q10c = row['Q10_C']
    q10d = row['Q10_D']
    
    if q10a == "Conducted a demographic analysis of the current workforce":
        s10 += point10
    if q10b == "Conducted a baseline culture analysis using employee feedback to identify gaps":
        s10 += point10
    if q10c == "Established goals regarding gender equity for the whole organization":
        s10 += point10
    if q10d == "Developed a timebound roadmap to meet established goals":
        s10 += point10

    # Q11:
    # Dedicated team responsible for establishing and tracking progress toward gender equity targets = 25%
    # Specific timeline on when targets should be met = 25%
    # Engagement with all staff on targets and their importance to the organization = 25%
    # Training of all employees who have a direct impact on meeting targets = 25%
    # No = 0%
    # Sum, no cap
    
    s11 = 0
    point11 = 0.25
    
    q11a = row['Q11_A']
    q11b = row['Q11_B']
    q11c = row['Q11_C']
    q11d = row['Q11_D']
    
    if q11a == "Dedicated team responsible for establishing and tracking progress toward gender equity targets":
        s9 += point11
    if q11b == "Specific timeline on when targets should be met":
        s9 += point11
    if q11c =="Engagement with all staff on targets and their importance to the organization":
        s9 += point11
    if q11d == "Training of all employees who have a direct impact on meeting targets":
        s9 += point11

    # Q10:
    # N/A - No targets set = 0%
    # Behind goals (<66% or fewer targets met) = 50%
    # Nearing goals (66-99% targets met) = 100%
    # Goals met = 100%
    # Goals exceeded = 100%
    # No Sum
    
    q14 = row['Q14']
    if q2 == 'Behind goals (<66% or fewer targets met)':
        s10 = 0.5
    elif q10 == 'Nearing goals (66-99% targets met)' or q10 == 'Goals met' or q10 == 'Goals exceeded': 
        s10 = 1
    else: #no targets set or NaN
        s10 = 0
    
    #preliminary score
    s = [s9, s10, s11, s12, s13, s14]
    
    return sum(map(lambda a, b: a * b, s, w))
#(s9 * w9) + (s10 * w10) + (s11 * w11) + (s12 * w12) + (s13 * w13) + (s14 * w14)

dfv.loc[:,'leader_prelim_score'] = dfv.apply(compute_score, axis = 1)
dfv.loc[:,'leader_weighted_score'] = dfv['leader_prelim_score'] * leader_weight

# Reverse indices so that Company 1A is listed first.
dfv.index = dfl.index.values[::-1]
dfv = dfv[::-1]
dfv
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'review_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-fbb001f98dca> in <module>
#     102 #(s9 * w9) + (s10 * w10) + (s11 * w11) + (s12 * w12) + (s13 * w13) + (s14 * w14)
#     103
# --> 104 dfv.loc[:,'leader_prelim_score'] = dfv.apply(compute_score, axis = 1)
#     105 dfv.loc[:,'leader_weighted_score'] = dfv['leader_prelim_score'] * leader_weight
#     106
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8734             kwargs=kwargs,
#    8735         )
# -> 8736         return op.apply()
#    8737
#    8738     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-24-fbb001f98dca> in compute_score(row)
#      22     # N/A, No EDI policy in place or NaN = 0%
#      23
# ---> 24     q1 = row['review_status']
#      25     if q1 == 'No':
#      26         s1 = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'review_status'
